# %%
import csv 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import pandas as pd
import heapq

# %%
sns.set('talk')

# %%
with open('life-expectancy-vs-gdp-per-capita.csv',newline='') as f:         #Ouverture du fichier CSV
    tableau=[]
    lire=csv.reader(f)                            #chargement des lignes du fichier csv
    print('',end='\n')
    print('Affichage des lignes du tableau',end='\n')
    for ligne in lire:                            #Pour chaque ligne... 
        #print(ligne, end='\n')                    #...affichage de la ligne dans la console ...
        tableau.append(ligne)                     #...on ajoute la ligne dans la liste ...
# Out:
# Affichage des lignes du tableau

# %%
del tableau[1]

# %%
for i in reversed(range(1,len(tableau))):
    k=tableau[i][2]
    k=int(k)
    if(k!=2015):
        del tableau[i]
tableau
# Out:
# [['Entity',
#   'Code',
#   'Year',
#   'Total population (Gapminder, HYDE & UN)',
#   'Continent',
#   'Life expectancy',
#   'Real GDP per capita in 2011US$, multiple benchmarks (Maddison Project Database (2018))'],
#  ['Afghanistan', 'AFG', '2015', '34414000', 'Asia', '63.377', '1928'],
#  ['Africa', '', '2015', '1182439040', '', '61.607', '4684'],
#  ['Akrotiri and Dhekelia', 'OWID_AKD', '2015', '', 'Asia', '', ''],
#  ['Albania', 'ALB', '2015', '2891000', 'Europe', '78.025', '10947'],
#  ['Algeria', 'DZA', '2015', '39728000', 'Africa', '76.09', '13024'],
#  ['American Samoa', 'ASM', '2015', '56000', 'Oceania', '73.588', ''],
#  ['Americas', '', '2015', '', '', '76.44286453', ''],
#  ['Andorra', 'AND', '2015', '78000', 'Europe', '83.073', ''],
#  ['Angola', 'AGO', '2015', '27884000', 'Africa', '59.398', '8631'],
#  ['Anguilla', 'AIA', '2015', '14000', 'North America', '81.332', ''],
#  ['Antarctica', 'ATA', '2015', '', 'Antarctica', '', ''],
#  ['Antigua and Barbuda',
#   'ATG',
#   '2015',
#   '94000',
#   'North America',
#   '76.483',
#   ''],
#  ['Argentina', 'ARG', '2015', '43075000', 'South America', '76.068', '19316'],
#  ['Armenia', 'ARM', '2015', '2926000', 'Asia', '74.467', '9552'],
#  ['Aruba', 'ABW', '2015', '104000', 'North America', '75.725', ''],
#  ['Asia', '', '2015', '4433475072', '', '72.62', ''],
#  ['Australia', 'AUS', '2015', '23932000', 'Oceania', '82.794', '44336'],
#  ['Austria', 'AUT', '2015', '8679000', 'Europe', '81.182', '44845'],
#  ['Austria-Hungary', 'OWID_AUH', '2015', '', 'Europe', '', ''],
#  ['Azerbaijan', 'AZE', '2015', '9623000', 'Asia', '72.266', '16045'],
#  ['Baden', 'OWID_BAD', '2015', '', 'Europe', '', ''],
#  ['Bahamas', 'BHS', '2015', '374000', 'North America', '73.088', ''],
#  ['Bahrain', 'BHR', '2015', '1372000', 'Asia', '76.762', '39197'],
#  ['Bangladesh', 'BGD', '2015', '156256000', 'Asia', '71.514', '3068'],
#  ['Barbados', 'BRB', '2015', '285000', 'North America', '78.801', '10030'],
#  ['Bavaria', 'OWID_BAV', '2015', '', 'Europe', '', ''],
#  ['Belarus', 'BLR', '2015', '9439000', 'Europe', '73.652', '19306'],
#  ['Belgium', 'BEL', '2015', '11288000', 'Europe', '80.969', '39531'],
#  ['Belize', 'BLZ', '2015', '361000', 'North America', '74.034', ''],
#  ['Benin', 'BEN', '2015', '10576000', 'Africa', '60.608', '2141'],
#  ['Bermuda', 'BMU', '2015', '64000', 'North America', '81.999', ''],
#  ['Bhutan', 'BTN', '2015', '728000', 'Asia', '70.419', ''],
#  ['Bolivia', 'BOL', '2015', '10870000', 'South America', '70.277', '5969'],
#  ['Bonaire Sint Eustatius and Saba',
#   'BES',
#   '2015',
#   '25000',
#   'North America',
#   '77.033',
#   ''],
#  ['Bosnia and Herzegovina',
#   'BIH',
#   '2015',
#   '3429000',
#   'Europe',
#   '76.865',
#   '10305'],
#  ['Botswana', 'BWA', '2015', '2121000', 'Africa', '67.338', '14626'],
#  ['Bouvet Island', 'BVT', '2015', '', 'Antarctica', '', ''],
#  ['Brazil', 'BRA', '2015', '204472000', 'South America', '74.994', '15377'],
#  ['British Indian Ocean Territory', 'IOT', '2015', '', 'Asia', '', ''],
#  ['British Virgin Islands',
#   'VGB',
#   '2015',
#   '29000',
#   'North America',
#   '78.411',
#   ''],
#  ['Brunei', 'BRN', '2015', '415000', 'Asia', '75.318', ''],
#  ['Bulgaria', 'BGR', '2015', '7200000', 'Europe', '74.584', '17254'],
#  ['Burkina Faso', 'BFA', '2015', '18111000', 'Africa', '59.919', '1527'],
#  ['Burundi', 'BDI', '2015', '10160000', 'Africa', '60.123', '723'],
#  ['Cambodia', 'KHM', '2015', '15521000', 'Asia', '68.637', '3139'],
#  ['Cameroon', 'CMR', '2015', '23298000', 'Africa', '57.583', '2754'],
#  ['Canada', 'CAN', '2015', '36027000', 'North America', '82.026', '42844'],
#  ['Cape Verde', 'CPV', '2015', '525000', 'Africa', '72.117', '6358'],
#  ['Cayman Islands', 'CYM', '2015', '62000', 'North America', '83.324', ''],
#  ['Central African Republic',
#   'CAF',
#   '2015',
#   '4493000',
#   'Africa',
#   '50.881',
#   '605'],
#  ['Chad', 'TCD', '2015', '14111000', 'Africa', '53.137', '2387'],
#  ['Channel Islands', 'OWID_CIS', '2015', '165000', 'Europe', '82.429', ''],
#  ['Chile', 'CHL', '2015', '17969000', 'South America', '79.646', '21340'],
#  ['China', 'CHN', '2015', '1406848000', 'Asia', '75.928', '12002'],
#  ['Christmas Island', 'CXR', '2015', '', 'Asia', '', ''],
#  ['Cocos Islands', 'CCK', '2015', '', 'Asia', '', ''],
#  ['Colombia', 'COL', '2015', '47521000', 'South America', '76.531', '12858'],
#  ['Comoros', 'COM', '2015', '777000', 'Africa', '63.471', '1706'],
#  ['Congo', 'COG', '2015', '4856000', 'Africa', '63.097', '4526'],
#  ['Cook Islands', 'COK', '2015', '18000', 'Oceania', '75.409', ''],
#  ['Costa Rica', 'CRI', '2015', '4848000', 'North America', '79.565', '13568'],
#  ["Cote d'Ivoire", 'CIV', '2015', '23226000', 'Africa', '56.065', '3473'],
#  ['Croatia', 'HRV', '2015', '4233000', 'Europe', '77.892', '20905'],
#  ['Cuba', 'CUB', '2015', '11325000', 'North America', '78.561', '7889'],
#  ['Curacao', 'CUW', '2015', '160000', 'North America', '78.268', ''],
#  ['Cyprus', 'CYP', '2015', '1161000', 'Europe', '80.35', '25903'],
#  ['Czech Republic', 'CZE', '2015', '10601000', 'Europe', '78.692', '30410'],
#  ['Czechoslovakia', 'OWID_CZS', '2015', '', 'Europe', '', '29361'],
#  ['Democratic Republic of Congo',
#   'COD',
#   '2015',
#   '76245000',
#   'Africa',
#   '59.254',
#   '836'],
#  ['Denmark', 'DNK', '2015', '5689000', 'Europe', '80.475', '44939'],
#  ['Djibouti', 'DJI', '2015', '914000', 'Africa', '64.136', '3258'],
#  ['Dominica', 'DMA', '2015', '71000', 'North America', '74.194', '9537'],
#  ['Dominican Republic',
#   'DOM',
#   '2015',
#   '10282000',
#   'North America',
#   '73.241',
#   '13382'],
#  ['East Asia', '', '2015', '', '', '', '9998'],
#  ['East Germany', 'OWID_GDR', '2015', '', 'Europe', '', ''],
#  ['Eastern Europe', '', '2015', '', '', '', '19187'],
#  ['Ecuador', 'ECU', '2015', '16212000', 'South America', '76.143', '10914'],
#  ['Egypt', 'EGY', '2015', '92443000', 'Africa', '71.302', '11236'],
#  ['El Salvador', 'SLV', '2015', '6325000', 'North America', '72.412', '8163'],
#  ['Equatorial Guinea', 'GNQ', '2015', '1169000', 'Africa', '57.359', '35743'],
#  ['Eritrea', 'ERI', '2015', '3343000', 'Africa', '64.664', ''],
#  ['Eritrea and Ethiopia', 'OWID_ERE', '2015', '', 'Africa', '', ''],
#  ['Estonia', 'EST', '2015', '1315000', 'Europe', '77.783', '25790'],
#  ['Ethiopia', 'ETH', '2015', '100835000', 'Africa', '65.048', '1576'],
#  ['Europe', '', '2015', '743059008', '', '77.839', ''],
#  ['Faeroe Islands', 'FRO', '2015', '48000', 'Europe', '80.13', ''],
#  ['Falkland Islands', 'FLK', '2015', '3000', 'South America', '80.876', ''],
#  ['Fiji', 'FJI', '2015', '869000', 'Oceania', '67.103', ''],
#  ['Finland', 'FIN', '2015', '5481000', 'Europe', '81.196', '37920'],
#  ['Former USSR', '', '2015', '', '', '', '17953'],
#  ['Former Yugoslavia', '', '2015', '', '', '', '15888'],
#  ['France', 'FRA', '2015', '64453000', 'Europe', '82.224', '38448'],
#  ['French Guiana', 'GUF', '2015', '261000', 'South America', '79.555', ''],
#  ['French Polynesia', 'PYF', '2015', '273000', 'Oceania', '76.787', ''],
#  ['French Southern Territories', 'ATF', '2015', '', 'Antarctica', '', ''],
#  ['Gabon', 'GAB', '2015', '1948000', 'Africa', '64.913', '14315'],
#  ['Gambia', 'GMB', '2015', '2086000', 'Africa', '60.91', '1948'],
#  ['Georgia', 'GEO', '2015', '4024000', 'Asia', '72.973', '10198'],
#  ['Germany', 'DEU', '2015', '81787000', 'Europe', '80.77', '46426'],
#  ['Ghana', 'GHA', '2015', '27849000', 'Africa', '62.772', '3687'],
#  ['Gibraltar', 'GIB', '2015', '34000', 'Europe', '79.351', ''],
#  ['Greece', 'GRC', '2015', '10660000', 'Europe', '81.548', '24545'],
#  ['Greenland', 'GRL', '2015', '56000', 'North America', '71.407', ''],
#  ['Grenada', 'GRD', '2015', '110000', 'North America', '72.445', ''],
#  ['Guadeloupe', 'GLP', '2015', '400000', 'North America', '81.22', ''],
#  ['Guam', 'GUM', '2015', '162000', 'Oceania', '79.144', ''],
#  ['Guatemala', 'GTM', '2015', '16252000', 'North America', '73.25', '7055'],
#  ['Guernsey', 'GGY', '2015', '', 'Europe', '', ''],
#  ['Guinea', 'GIN', '2015', '11432000', 'Africa', '59.598', '1606'],
#  ['Guinea-Bissau', 'GNB', '2015', '1737000', 'Africa', '56.959', '1313'],
#  ['Guyana', 'GUY', '2015', '767000', 'South America', '69.262', ''],
#  ['Haiti', 'HTI', '2015', '10696000', 'North America', '62.485', '1649'],
#  ['Hanover', 'OWID_HAN', '2015', '', 'Europe', '', ''],
#  ['Heard Island and McDonald Islands',
#   'HMD',
#   '2015',
#   '',
#   'Antarctica',
#   '',
#   ''],
#  ['Hesse Electoral', 'OWID_HSE', '2015', '', 'Europe', '', ''],
#  ['Hesse Grand Ducal', 'OWID_HSG', '2015', '', 'Europe', '', ''],
#  ['Honduras', 'HND', '2015', '9113000', 'North America', '74.495', '4352'],
#  ['Hong Kong', 'HKG', '2015', '7186000', 'Asia', '84.043', '46504'],
#  ['Hungary', 'HUN', '2015', '9778000', 'Europe', '76.006', '23539'],
#  ['Iceland', 'ISL', '2015', '330000', 'Europe', '82.481', '40572'],
#  ['India', 'IND', '2015', '1310151936', 'Asia', '68.607', '5639'],
#  ['Indonesia', 'IDN', '2015', '258383008', 'Asia', '70.768', '10099'],
#  ['Iran', 'IRN', '2015', '78492000', 'Asia', '75.796', '15039'],
#  ['Iraq', 'IRQ', '2015', '35572000', 'Asia', '69.929', '13087'],
#  ['Ireland', 'IRL', '2015', '4652000', 'Europe', '81.344', '53372'],
#  ['Isle of Man', 'IMN', '2015', '83000', 'Europe', '80.82', ''],
#  ['Israel', 'ISR', '2015', '7978000', 'Asia', '82.34', '31729'],
#  ['Italy', 'ITA', '2015', '60578000', 'Europe', '82.828', '34673'],
#  ['Jamaica', 'JAM', '2015', '2891000', 'North America', '74.098', '7115'],
#  ['Japan', 'JPN', '2015', '127985000', 'Asia', '83.879', '36030'],
#  ['Jersey', 'JEY', '2015', '', 'Europe', '', ''],
#  ['Jordan', 'JOR', '2015', '9267000', 'Asia', '74.078', '11738'],
#  ['Kazakhstan', 'KAZ', '2015', '17572000', 'Asia', '71.319', '23408'],
#  ['Kenya', 'KEN', '2015', '47878000', 'Africa', '64.798', '3090'],
#  ['Kiribati', 'KIR', '2015', '111000', 'Oceania', '67.291', ''],
#  ['Kosovo', 'OWID_KOS', '2015', '', 'Europe', '', ''],
#  ['Kuwait', 'KWT', '2015', '3836000', 'Asia', '75.13', '68127'],
#  ['Kyrgyzstan', 'KGZ', '2015', '5959000', 'Asia', '70.876', '5910'],
#  ['Laos', 'LAO', '2015', '6741000', 'Asia', '66.546', '6001'],
#  ['Latin America', '', '2015', '623934016', '', '', '14400'],
#  ['Latin America and the Caribbean', '', '2015', '', '', '74.852', ''],
#  ['Latvia', 'LVA', '2015', '1998000', 'Europe', '74.733', '22724'],
#  ['Lebanon', 'LBN', '2015', '6533000', 'Asia', '78.768', '12665'],
#  ['Lesotho', 'LSO', '2015', '2059000', 'Africa', '51.038', '2954'],
#  ['Liberia', 'LBR', '2015', '4472000', 'Africa', '62.269', '798'],
#  ['Libya', 'LBY', '2015', '6418000', 'Africa', '72.121', '8514'],
#  ['Liechtenstein', 'LIE', '2015', '37000', 'Europe', '82.039', ''],
#  ['Lithuania', 'LTU', '2015', '2932000', 'Europe', '74.923', '25279'],
#  ['Luxembourg', 'LUX', '2015', '567000', 'Europe', '81.636', '67804'],
#  ['Macao', 'MAC', '2015', '602000', 'Asia', '83.707', ''],
#  ['Macedonia', 'MKD', '2015', '2079000', 'Europe', '75.406', '13586'],
#  ['Madagascar', 'MDG', '2015', '24234000', 'Africa', '65.539', '1288'],
#  ['Malawi', 'MWI', '2015', '16745000', 'Africa', '61.953', '960'],
#  ['Malaysia', 'MYS', '2015', '30271000', 'Asia', '75.461', '22075'],
#  ['Maldives', 'MDV', '2015', '455000', 'Asia', '77.691', ''],
#  ['Mali', 'MLI', '2015', '17439000', 'Africa', '57.509', '1563'],
#  ['Malta', 'MLT', '2015', '434000', 'Europe', '81.896', '26577'],
#  ['Marshall Islands', 'MHL', '2015', '57000', 'Oceania', '72.789', ''],
#  ['Martinique', 'MTQ', '2015', '378000', 'North America', '81.753', ''],
#  ['Mauritania', 'MRT', '2015', '4046000', 'Africa', '63.936', '3323'],
#  ['Mauritius', 'MUS', '2015', '1259000', 'Africa', '74.5', '18259'],
#  ['Mayotte', 'MYT', '2015', '240000', 'Africa', '79.408', ''],
#  ['Mecklenburg Schwerin', 'OWID_MEC', '2015', '', 'Europe', '', ''],
#  ['Mexico', 'MEX', '2015', '121858000', 'North America', '74.904', '15766'],
#  ['Micronesia (country)', 'FSM', '2015', '109000', 'Oceania', '67.315', ''],
#  ['Modena', 'OWID_MOD', '2015', '', 'Europe', '', ''],
#  ['Moldova', 'MDA', '2015', '4071000', 'Europe', '71.478', '5569'],
#  ['Monaco', 'MCO', '2015', '38000', 'Europe', '85.739', ''],
#  ['Mongolia', 'MNG', '2015', '2998000', 'Asia', '69.111', '11139'],
#  ['Montenegro', 'MNE', '2015', '627000', 'Europe', '76.452', '17738'],
#  ['Montserrat', 'MSR', '2015', '5000', 'North America', '74.339', ''],
#  ['Morocco', 'MAR', '2015', '34664000', 'Africa', '75.726', '7577'],
#  ['Mozambique', 'MOZ', '2015', '27042000', 'Africa', '57.206', '1277'],
#  ['Myanmar', 'MMR', '2015', '52681000', 'Asia', '65.81', '5834'],
#  ['Nagorno-Karabakh', 'OWID_NAG', '2015', '', 'Asia', '', ''],
#  ['Namibia', 'NAM', '2015', '2315000', 'Africa', '62.119', '11850'],
#  ['Nauru', 'NRU', '2015', '10000', 'Oceania', '59.758', ''],
#  ['Nepal', 'NPL', '2015', '27015000', 'Asia', '69.515', '2607'],
#  ['Netherlands', 'NLD', '2015', '16938000', 'Europe', '81.715', '48463'],
#  ['Netherlands Antilles', 'ANT', '2015', '', 'North America', '', ''],
#  ['New Caledonia', 'NCL', '2015', '271000', 'Oceania', '76.827', ''],
#  ['New Zealand', 'NZL', '2015', '4615000', 'Oceania', '81.713', '33445'],
#  ['Nicaragua', 'NIC', '2015', '6223000', 'North America', '73.649', '4699'],
#  ['Niger', 'NER', '2015', '20002000', 'Africa', '60.631', '895'],
#  ['Nigeria', 'NGA', '2015', '181136992', 'Africa', '53.112', '5540'],
#  ['Niue', 'NIU', '2015', '2000', 'Oceania', '73.135', ''],
#  ['Norfolk Island', 'NFK', '2015', '', 'Oceania', '', ''],
#  ['North America', '', '2015', '357031008', '', '', ''],
#  ['North Korea', 'PRK', '2015', '25184000', 'Asia', '71.481', '1720'],
#  ['Northern America', '', '2015', '', '', '79.223', ''],
#  ['Northern Cyprus', 'OWID_CYN', '2015', '', 'Asia', '', ''],
#  ['Northern Mariana Islands', 'MNP', '2015', '56000', 'Oceania', '75.279', ''],
#  ['Norway', 'NOR', '2015', '5200000', 'Europe', '81.912', '76305'],
#  ['Oceania', '', '2015', '39859000', '', '77.92', ''],
#  ['Oman', 'OMN', '2015', '4267000', 'Asia', '76.887', '37096'],
#  ['Pakistan', 'PAK', '2015', '199427008', 'Asia', '66.577', '5056'],
#  ['Palau', 'PLW', '2015', '18000', 'Oceania', '72.834', ''],
#  ['Palestine', 'PSE', '2015', '4529000', 'Asia', '73.442', '4422'],
#  ['Panama', 'PAN', '2015', '3968000', 'North America', '77.776', '20809'],
#  ['Papua New Guinea', 'PNG', '2015', '8108000', 'Oceania', '63.466', ''],
#  ['Paraguay', 'PRY', '2015', '6689000', 'South America', '73.662', '8364'],
#  ['Parma', 'OWID_PMA', '2015', '', 'Europe', '', ''],
#  ['Peru', 'PER', '2015', '30471000', 'South America', '75.792', '11215'],
#  ['Philippines', 'PHL', '2015', '102113000', 'Asia', '70.644', '6870'],
#  ['Pitcairn', 'PCN', '2015', '', 'Oceania', '', ''],
#  ['Poland', 'POL', '2015', '38034000', 'Europe', '77.859', '25310'],
#  ['Portugal', 'PRT', '2015', '10368000', 'Europe', '81.224', '27255'],
#  ['Puerto Rico', 'PRI', '2015', '3382000', 'North America', '79.52', '35384'],
#  ['Qatar', 'QAT', '2015', '2566000', 'Asia', '79.758', '139542'],
#  ['Republic of Vietnam', 'OWID_RVN', '2015', '', 'Asia', '', ''],
#  ['Reunion', 'REU', '2015', '863000', 'Africa', '79.775', ''],
#  ['Romania', 'ROU', '2015', '19925000', 'Europe', '75.476', '20549'],
#  ['Russia', 'RUS', '2015', '144984992', 'Europe', '71.464', '23118'],
#  ['Rwanda', 'RWA', '2015', '11369000', 'Africa', '67.45', '1676'],
#  ['Saint Barthlemy', '', '2015', '10000', '', '81.114', ''],
#  ['Saint BarthÃ©lemy', 'BLM', '2015', '', 'North America', '', ''],
#  ['Saint Helena', 'SHN', '2015', '6000', 'Africa', '80.202', ''],
#  ['Saint Kitts and Nevis',
#   'KNA',
#   '2015',
#   '51000',
#   'North America',
#   '75.532',
#   ''],
#  ['Saint Lucia', 'LCA', '2015', '179000', 'North America', '75.596', '10687'],
#  ['Saint Martin (French part)',
#   'MAF',
#   '2015',
#   '36000',
#   'North America',
#   '81.092',
#   ''],
#  ['Saint Pierre and Miquelon',
#   'SPM',
#   '2015',
#   '6000',
#   'North America',
#   '80.533',
#   ''],
#  ['Saint Vincent and the Grenadines',
#   'VCT',
#   '2015',
#   '109000',
#   'North America',
#   '72.095',
#   ''],
#  ['Samoa', 'WSM', '2015', '194000', 'Oceania', '72.73', ''],
#  ['San Marino', 'SMR', '2015', '33000', 'Europe', '84.375', ''],
#  ['Sao Tome and Principe',
#   'STP',
#   '2015',
#   '199000',
#   'Africa',
#   '69.377',
#   '3560'],
#  ['Saudi Arabia', 'SAU', '2015', '31718000', 'Asia', '74.651', '47737'],
#  ['Saxony', 'OWID_SAX', '2015', '', 'Europe', '', ''],
#  ['Senegal', 'SEN', '2015', '14578000', 'Africa', '66.747', '2446'],
#  ['Serbia', 'SRB', '2015', '8877000', 'Europe', '75.309', '13556'],
#  ['Serbia and Montenegro', 'OWID_SRM', '2015', '', 'Europe', '', ''],
#  ['Serbia excluding Kosovo', 'OWID_SEK', '2015', '', 'Europe', '', ''],
#  ['Seychelles', 'SYC', '2015', '95000', 'Africa', '73.182', '23984'],
#  ['Sierra Leone', 'SLE', '2015', '7172000', 'Africa', '52.941', '1033'],
#  ['Singapore', 'SGP', '2015', '5592000', 'Asia', '82.877', '67110'],
#  ['Sint Maarten (Dutch part)',
#   'SXM',
#   '2015',
#   '40000',
#   'North America',
#   '78.36',
#   ''],
#  ['Slovakia', 'SVK', '2015', '5436000', 'Europe', '76.827', '25896'],
#  ['Slovenia', 'SVN', '2015', '2071000', 'Europe', '80.673', '28077'],
#  ['Solomon Islands', 'SLB', '2015', '603000', 'Oceania', '72.173', ''],
#  ['Somalia', 'SOM', '2015', '13797000', 'Africa', '55.92', ''],
#  ['Somaliland', 'OWID_SML', '2015', '', 'Africa', '', ''],
#  ['South Africa', 'ZAF', '2015', '55386000', 'Africa', '62.649', '12054'],
#  ['South Georgia and the South Sandwich Islands',
#   'SGS',
#   '2015',
#   '',
#   'South America',
#   '',
#   ''],
#  ['South Korea', 'KOR', '2015', '50823000', 'Asia', '82.1', '35316'],
#  ['South Ossetia', 'OWID_SOS', '2015', '', 'Asia', '', ''],
#  ['South Sudan', 'SSD', '2015', '10716000', 'Africa', '56.855', ''],
#  ['Spain', 'ESP', '2015', '46672000', 'Europe', '82.981', '33376'],
#  ['Sri Lanka', 'LKA', '2015', '20908000', 'Asia', '76.316', '10734'],
#  ['Sudan', 'SDN', '2015', '38903000', 'Africa', '64.429', '3723'],
#  ['Suriname', 'SUR', '2015', '559000', 'South America', '71.249', ''],
#  ['Svalbard and Jan Mayen', 'SJM', '2015', '', 'Europe', '', ''],
#  ['Swaziland', 'SWZ', '2015', '1104000', 'Africa', '55.359', '7726'],
#  ['Sweden', 'SWE', '2015', '9765000', 'Europe', '82.251', '43464'],
#  ['Switzerland', 'CHE', '2015', '8297000', 'Europe', '83.142', '61476'],
#  ['Syria', 'SYR', '2015', '17997000', 'Asia', '69.908', '3509'],
#  ['Taiwan', 'TWN', '2015', '23557000', 'Asia', '79.743', '41805'],
#  ['Tajikistan', 'TJK', '2015', '8454000', 'Asia', '70.137', '3365'],
#  ['Tanzania', 'TZA', '2015', '51483000', 'Africa', '63.111', '2429'],
#  ['Thailand', 'THA', '2015', '68715000', 'Asia', '76.091', '13938'],
#  ['Timor', 'TLS', '2015', '1196000', 'Asia', '68.459', ''],
#  ['Togo', 'TGO', '2015', '7323000', 'Africa', '59.927', '1482'],
#  ['Tokelau', 'TKL', '2015', '1000', 'Oceania', '81.065', ''],
#  ['Tonga', 'TON', '2015', '101000', 'Oceania', '70.517', ''],
#  ['Transnistria', 'OWID_TRS', '2015', '', 'Europe', '', ''],
#  ['Trinidad and Tobago',
#   'TTO',
#   '2015',
#   '1370000',
#   'North America',
#   '72.941',
#   '30892'],
#  ['Tunisia', 'TUN', '2015', '11180000', 'Africa', '75.922', '10608'],
#  ['Turkey', 'TUR', '2015', '78529000', 'Asia', '76.532', '20808'],
#  ['Turkmenistan', 'TKM', '2015', '5565000', 'Asia', '67.704', '21262'],
#  ['Turks and Caicos Islands',
#   'TCA',
#   '2015',
#   '36000',
#   'North America',
#   '79.594',
#   ''],
#  ['Tuscany', 'OWID_TUS', '2015', '', 'Europe', '', ''],
#  ['Tuvalu', 'TUV', '2015', '11000', 'Oceania', '66.457', ''],
#  ['Two Sicilies', 'OWID_SIC', '2015', '', 'Europe', '', ''],
#  ['USSR', 'OWID_USS', '2015', '', 'Europe', '', ''],
#  ['Uganda', 'UGA', '2015', '38225000', 'Africa', '61.373', '1883'],
#  ['Ukraine', 'UKR', '2015', '44922000', 'Europe', '71.535', '9429'],
#  ['United Arab Emirates', 'ARE', '2015', '9263000', 'Asia', '77.285', '69237'],
#  ['United Kingdom', 'GBR', '2015', '65860000', 'Europe', '81.052', '38749'],
#  ['United Korea', 'OWID_KRU', '2015', '', 'Asia', '', ''],
#  ['United States',
#   'USA',
#   '2015',
#   '320878016',
#   'North America',
#   '78.91',
#   '52591'],
#  ['United States Minor Outlying Islands',
#   'UMI',
#   '2015',
#   '',
#   'Oceania',
#   '',
#   ''],
#  ['United States Virgin Islands',
#   'VIR',
#   '2015',
#   '105000',
#   'North America',
#   '79.914',
#   ''],
#  ['Uruguay', 'URY', '2015', '3412000', 'South America', '77.369', '19668'],
#  ['Uzbekistan', 'UZB', '2015', '30930000', 'Asia', '70.928', '9107'],
#  ['Vanuatu', 'VUT', '2015', '271000', 'Oceania', '69.869', ''],
#  ['Vatican', 'VAT', '2015', '1000', 'Europe', '74.344', ''],
#  ['Venezuela', 'VEN', '2015', '30082000', 'South America', '72.584', '16257'],
#  ['Vietnam', 'VNM', '2015', '92677000', 'Asia', '75.11', '5733'],
#  ['Wallis and Futuna', 'WLF', '2015', '12000', 'Oceania', '79.3', ''],
#  ['West Germany', 'OWID_GFR', '2015', '', 'Europe', '', ''],
#  ['Western Asia', '', '2015', '', '', '', '21226'],
#  ['Western Europe', '', '2015', '', '', '', '40175'],
#  ['Western Offshoots', '', '2015', '', '', '', '50951'],
#  ['Western Sahara', 'ESH', '2015', '526000', 'Africa', '69.213', ''],
#  ['World', 'OWID_WRL', '2015', '7379796992', '', '71.661', '14500'],
#  ['Wuerttemburg', 'OWID_WRT', '2015', '', 'Europe', '', ''],
#  ['Yemen', 'YEM', '2015', '26498000', 'Asia', '66.085', '2496'],
#  ['Yemen Arab Republic', 'OWID_YAR', '2015', '', 'Asia', '', ''],
#  ["Yemen People's Republic", 'OWID_YPR', '2015', '', 'Asia', '', ''],
#  ['Yugoslavia', 'OWID_YGS', '2015', '', 'Europe', '', ''],
#  ['Zambia', 'ZMB', '2015', '15879000', 'Africa', '61.737', '3537'],
#  ['Zanzibar', 'OWID_ZAN', '2015', '', 'Africa', '', ''],
#  ['Zimbabwe', 'ZWE', '2015', '13815000', 'Africa', '59.534', '1759'],
#  ['Ã…land Islands', 'ALA', '2015', '', 'Europe', '', '']]

# %%
gdp=[]
life_expectancy=[]
labels=[]
population=[]
population_plot=[]
continent =[]
color=[]
for i in range (len(tableau)):
    gdp.append(tableau[i][6])
    labels.append(tableau[i][0])
    life_expectancy.append(tableau[i][5])
    population.append(tableau[i][3])
    continent.append(tableau[i][4])
print(len(gdp),len(life_expectancy),len(labels),len(population))

for i in reversed(range(1,len(gdp))):
    k=tableau[i][6]
    l=tableau[i][5]
    m=tableau[i][1]
    n=tableau[i][4]
    if(k=='' or l=='' or m=='' or n ==''):
        del gdp[i]
        del life_expectancy[i]
        del labels[i]
        del population[i]
        del continent[i]

for i in range(1,len(gdp)):
    if (continent[i]== 'Europe'):
        color.append("red")
    if (continent[i]== 'Asia'):
        color.append("blue")
    if (continent[i]== 'Africa'):
        color.append("green")
    if (continent[i]== 'North America'):
        color.append("purple")
    if (continent[i]=='South America'):
        color.append("orange")
    if (continent[i]== 'Oceania'):
        color.append("beige")
    if (continent[i]== 'Antarctica'):
        color.append("brown")
# Out:
# 303 303 303 303

# %%
best_countries=[]
best_lifeExpt=[]
dataFrameG=[]
for i in range(1,len(life_expectancy)):
    gdp[i]=int(gdp[i])
    life_expectancy[i]=float(life_expectancy[i])
    population_plot.append(int(population[i])/1000000)
print(len(gdp),len(life_expectancy),len(color),len(population_plot))

lifexpt_mean=np.mean(life_expectancy[1:])
std_lifexpt=np.std(life_expectancy[1:])
stand_abobeMean=lifexpt_mean+std_lifexpt


del life_expectancy[0]
del labels[0]
del gdp[0]

for i in range(len(life_expectancy)):
    if (life_expectancy[i]>stand_abobeMean):
        best_countries.append(labels[i])
        best_lifeExpt.append(life_expectancy[i])
    
        
dataFrameG=np.vstack(( best_countries,best_lifeExpt))
Test=np.transpose(dataFrameG)
columns = ['Country','Life Expectancy']
df = pd.DataFrame(data=Test,columns=columns)

df.style.format("{:.20}")
# Out:
# 167 167 166 166
# <style  type="text/css" >
# </style><table id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >Life Expectancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow0_col0" class="data row0 col0" >Australia</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow0_col1" class="data row0 col1" >82.794</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow1_col0" class="data row1 col0" >Austria</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow1_col1" class="data row1 col1" >81.182</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow2_col0" class="data row2 col0" >Belgium</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow2_col1" class="data row2 col1" >80.969</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow3_col0" class="data row3 col0" >Canada</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow3_col1" class="data row3 col1" >82.026</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow4_col0" class="data row4 col0" >Cyprus</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow4_col1" class="data row4 col1" >80.35</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow5_col0" class="data row5 col0" >Denmark</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow5_col1" class="data row5 col1" >80.475</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow6_col0" class="data row6 col0" >Finland</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow6_col1" class="data row6 col1" >81.196</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow7_col0" class="data row7 col0" >France</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow7_col1" class="data row7 col1" >82.224</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow8_col0" class="data row8 col0" >Germany</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow8_col1" class="data row8 col1" >80.77</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow9_col0" class="data row9 col0" >Greece</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow9_col1" class="data row9 col1" >81.548</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow10_col0" class="data row10 col0" >Hong Kong</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow10_col1" class="data row10 col1" >84.043</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow11_col0" class="data row11 col0" >Iceland</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow11_col1" class="data row11 col1" >82.481</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow12_col0" class="data row12 col0" >Ireland</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow12_col1" class="data row12 col1" >81.344</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow13_col0" class="data row13 col0" >Israel</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow13_col1" class="data row13 col1" >82.34</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow14_col0" class="data row14 col0" >Italy</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow14_col1" class="data row14 col1" >82.828</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow15_col0" class="data row15 col0" >Japan</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow15_col1" class="data row15 col1" >83.879</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow16_col0" class="data row16 col0" >Luxembourg</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow16_col1" class="data row16 col1" >81.636</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow17_col0" class="data row17 col0" >Malta</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow17_col1" class="data row17 col1" >81.896</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow18_col0" class="data row18 col0" >Netherlands</td>
#                         <td id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6crow18_col1" class="data row18 col1" >81.715</td>
#             </tr>
#             <tr>
#                         <th id="T_458c9a70_2463_11eb_9ecd_97c2a7f03b6clevel0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_458c9

# %%
#population
fig,ax = plt.subplots(1, 1, figsize=(20, 10))
ax.set_xscale("log")


for i in range((len(gdp))): 
    ax.scatter(gdp[i],life_expectancy[i],c=color[i],s=population_plot[i],alpha=0.4)
    if (labels[i]=='China' or labels[i]=='Japan'or labels[i]=='Sweden' or labels[i]=='Norway'
        or labels[i]=='Nigeria' or labels[i]=='Burkina Faso' or labels[i]=='Qatar'or labels[i]=='India'
        or labels[i]=='Brazil'or labels[i]=='United States'or labels[i]=='Russia'):
        ax.annotate(labels[i],(gdp[i], life_expectancy[i]),xytext=(gdp[i],life_expectancy[i]+2),fontsize=15, arrowprops=dict(facecolor=color[i], shrink=0.05))
   
ax.hlines(stand_abobeMean,np.min(gdp),np.max(gdp), color='green',alpha=0.6,label='Life Expectancy standard deviation above the mean ')
ax.hlines(np.mean(life_expectancy),np.min(gdp),np.max(gdp), color='blue',alpha=0.6,label='Average life expectancy')
ax.vlines(np.mean(gdp),(np.min(life_expectancy)),np.max(life_expectancy), color='red',alpha=0.6,label='GDP standard deviation above the mean?')



ax.set_xlabel('GDP per capita (in $)')
ax.set_ylabel('Life expectancy (in years)')
ax.set_title('GDP per capita VS Life expectancy in 2015 log scale')
leg1=ax.legend(prop={"size":10},loc='lower left')


red_patch = mpatches.Patch(color='red', label='Europe')
blue_patch = mpatches.Patch(color='blue', label='Asia')
orange_patch = mpatches.Patch(color='orange', label='South America')
green_patch = mpatches.Patch(color='green', label='Africa')
purple_patch = mpatches.Patch(color='purple', label='North America')
brown_patch = mpatches.Patch(color='brown', label='Antartica')
beige_patch = mpatches.Patch(color='black', label='Oceania')

leg2=ax.legend(handles=[red_patch,blue_patch,orange_patch,green_patch,purple_patch,brown_patch,beige_patch],prop={"size":10},loc='lower right')

ax.add_artist(leg1)
del population[0]

# %%
# e High life but low gdp
mix_countries=[]
high_lifeExpt=[]
low_GDP=[]
dataFrameM=[]
lim_gdp=9000
lim_exp=70
for i in range((len(gdp))):
    if (gdp[i]<lim_gdp and life_expectancy[i]>lim_exp):
        mix_countries.append(labels[i])
        low_GDP.append(gdp[i])
        high_lifeExpt.append(life_expectancy[i])
        
        
dataFrameM=np.vstack(( mix_countries,low_GDP,high_lifeExpt))
Test=np.transpose(dataFrameM)
columns = ['Country','GDP','Life Expectancy',]
df = pd.DataFrame(data=Test,columns=columns)

df.style.format("{:.20}")
# Out:
# <style  type="text/css" >
# </style><table id="T_482b373e_2463_11eb_b16a_97c2a7f03b6c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country</th>        <th class="col_heading level0 col1" >GDP</th>        <th class="col_heading level0 col2" >Life Expectancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow0_col0" class="data row0 col0" >Bangladesh</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow0_col1" class="data row0 col1" >3068</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow0_col2" class="data row0 col2" >71.514</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow1_col0" class="data row1 col0" >Bolivia</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow1_col1" class="data row1 col1" >5969</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow1_col2" class="data row1 col2" >70.277</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow2_col0" class="data row2 col0" >Cape Verde</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow2_col1" class="data row2 col1" >6358</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow2_col2" class="data row2 col2" >72.117</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow3_col0" class="data row3 col0" >Cuba</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow3_col1" class="data row3 col1" >7889</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow3_col2" class="data row3 col2" >78.561</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow4_col0" class="data row4 col0" >El Salvador</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow4_col1" class="data row4 col1" >8163</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow4_col2" class="data row4 col2" >72.412</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow5_col0" class="data row5 col0" >Guatemala</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow5_col1" class="data row5 col1" >7055</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow5_col2" class="data row5 col2" >73.25</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow6_col0" class="data row6 col0" >Honduras</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow6_col1" class="data row6 col1" >4352</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow6_col2" class="data row6 col2" >74.495</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow7_col0" class="data row7 col0" >Jamaica</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow7_col1" class="data row7 col1" >7115</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow7_col2" class="data row7 col2" >74.098</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow8_col0" class="data row8 col0" >Kyrgyzstan</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow8_col1" class="data row8 col1" >5910</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow8_col2" class="data row8 col2" >70.876</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow9_col0" class="data row9 col0" >Libya</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow9_col1" class="data row9 col1" >8514</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow9_col2" class="data row9 col2" >72.121</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow10_col0" class="data row10 col0" >Moldova</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow10_col1" class="data row10 col1" >5569</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow10_col2" class="data row10 col2" >71.478</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow11_col0" class="data row11 col0" >Morocco</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow11_col1" class="data row11 col1" >7577</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow11_col2" class="data row11 col2" >75.726</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow12_col0" class="data row12 col0" >Nicaragua</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow12_col1" class="data row12 col1" >4699</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow12_col2" class="data row12 col2" >73.649</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow13_col0" class="data row13 col0" >North Korea</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow13_col1" class="data row13 col1" >1720</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow13_col2" class="data row13 col2" >71.481</td>
#             </tr>
#             <tr>
#                         <th id="T_482b373e_2463_11eb_b16a_97c2a7f03b6clevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow14_col0" class="data row14 col0" >Palestine</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow14_col1" class="data row14 col1" >4422</td>
#                         <td id="T_482b373e_2463_11eb_b16a_97c2a7f03b6crow14_col2" class="data row14 col2" >73.

# %%
#f 
inequal_country=[]
inequal_lifeExp=[]
highLE_LowGDP_C=[]
highLE_LowGDP=[]
fig2,ax2 = plt.subplots(1, 1, figsize=(20, 4))
ax2.set_xscale("log")
total_gdp=[]
treshold_e=40

for i in range(len(gdp)):
    total_gdp.append(int(gdp[i])*int(population[i])/1000000000)
test=np.std(total_gdp)+np.mean(total_gdp)
for i in range((len(gdp))): 
    ax2.scatter(total_gdp[i],life_expectancy[i],c=color[i],s=population_plot[i],alpha=0.4)

for i in range(len(life_expectancy)):
    if (life_expectancy[i]<np.mean(life_expectancy) and total_gdp[i]>test):
        inequal_country.append(labels[i])
        inequal_lifeExp.append(life_expectancy[i])
        
#ax2.hlines(stand_abobeMean,np.min(gdp),np.max(gdp), color='green',alpha=0.6,label='Life Expectancy standard deviation above the mean ')
#ax2.hlines(np.mean(life_expectancy),np.min(gdp),np.max(gdp), color='blue',alpha=0.6,label='Average life expectancy')
ax2.vlines((np.mean(total_gdp)+np.std(total_gdp)),(np.min(life_expectancy)),np.max(life_expectancy), color='red',alpha=0.6,label='GDP standard deviation above the mean? + One std')
ax2.hlines(np.mean(life_expectancy),np.min(total_gdp),np.max(total_gdp), color='blue',alpha=0.6,label='Average life expectancy')
inequal_country
# Out:
# ['India', 'Russia']

# %%
#Part 2
with open('suicide-rate.csv',newline='') as f:         #Ouverture du fichier CSV
    tableau=[]
    lire=csv.reader(f)                            #chargement des lignes du fichier csv
    print('',end='\n')
    print('Affichage des lignes du tableau',end='\n')
    for ligne in lire:                            #Pour chaque ligne... 
        #print(ligne, end='\n')                    #...affichage de la ligne dans la console ...
        tableau.append(ligne)  

del tableau[0]#...on ajoute la ligne dans la liste ...

for i in reversed(range(1,len(tableau))):
    k=tableau[i][2]
    k=int(k)
    if(k!=2016):
        del tableau[i]

labels=[]
suicidal_rate=[]

color=[]
for i in range (len(tableau)):
    labels.append(tableau[i][0])
    suicidal_rate.append(tableau[i][3])

for i in reversed(range(1,len(labels))):
    k=tableau[i][0]
    l=tableau[i][3]
    if(k=='' or l=='' ):
        del labels[i]
        del suicidal_rate[i]
        
countries=[]
most_suicide=heapq.nlargest(100, suicidal_rate)
for i in range (len(tableau)):
    for j in range (len(most_suicide)):
        if suicidal_rate[i]==most_suicide[j]:
            countries.append(labels[i])
# Out:
# Affichage des lignes du tableau

# %%
dataFrameZ=np.vstack((labels,suicidal_rate))
Test=np.transpose(dataFrameZ)
columns = ['Country','Suicidal rate',]
df = pd.DataFrame(data=Test,columns=columns)
df['Suicidal rate']=df['Suicidal rate'].astype('float64')
df.style.format("{:.20}");

# %%
df['Suicidal rate'].mean()
# Out:
# 9.347390841922156

# %%
rich_countries=pd.concat([df.loc[df['Country']=='Norway'],df.loc[df['Country']=='Sweden'],
                         df.loc[df['Country']=='United States'],df.loc[df['Country']=='Japan'],
                         df.loc[df['Country']=='China'],df.loc[df['Country']=='South Korea'],
                         df.loc[df['Country']=='Canada']]).sort_values(by=['Suicidal rate'])

# %%
 rich_countries.plot.bar(x='Country',y='Suicidal rate',rot=0,figsize=(13,5),color='r')

# %%
low_suicide_countries=df.nsmallest(4,'Suicidal rate')
low_suicide_countries.plot.bar(x='Country',y='Suicidal rate',rot=0,figsize=(15,5),color='g')

# %%
fig,ax = plt.subplots(1, 1, figsize=(20, 5))
mix_countries=pd.concat([rich_countries,low_suicide_countries]).sort_values(by=['Suicidal rate'])
ax.bar(mix_countries['Country'],mix_countries['Suicidal rate'],color='orange')
ax.axhline(df['Suicidal rate'].mean(), color='r', linestyle='--',label='Average suicidal rate')
ax.set_title('Suicidal rate per 100,000 population in 2016')
leg1=ax.legend(prop={"size":20},loc='upper left')
plt.show()

# %%
#Part 2
with open('global-hunger-index.csv',newline='') as f:      
    tableau=[]
    lire=csv.reader(f)                            
    print('',end='\n')
    for ligne in lire:                           
        tableau.append(ligne)                     
        
del tableau[0]

for i in reversed(range(1,len(tableau))):
    k=tableau[i][2]
    k=int(k)
    if(k!=2018):
        del tableau[i]
        
labels=[]
hunger_rate=[]

for i in range (len(tableau)):
    labels.append(tableau[i][0])
    hunger_rate.append(tableau[i][3])

for i in reversed(range(1,len(labels))):
    k=tableau[i][0]
    l=tableau[i][3]
    if(k=='' or l=='' ):
        del labels[i]
        del hunger_rate[i]
        
countries=[]
most_hunger=heapq.nlargest(100, hunger_rate)
for i in range (len(tableau)):
    for j in range (len(most_hunger)):
        if suicidal_rate[i]==most_hunger[j]:
            countries.append(labels[i])

# %%
dataFrameH=np.vstack((labels,hunger_rate))
Test=np.transpose(dataFrameH)
columns = ['Country','Hunger rate',]
dh = pd.DataFrame(data=Test,columns=columns)
dh['Hunger rate']=dh['Hunger rate'].astype('float64')
dh.style.format("{:.20}");

# %%
high_hunger_countries=dh.nlargest(7,'Hunger rate')
fig,ax = plt.subplots(1, 1, figsize=(13, 5))
ax.bar(high_hunger_countries['Country'],high_hunger_countries['Hunger rate'],color='red')
ax.axhline(dh['Hunger rate'].mean(), color='black', linestyle='--',label='Average hunger rate')
ax.set_title('Global Hunger index in 2018')
leg1=ax.legend(prop={"size":10},loc='upper right')
plt.show()
