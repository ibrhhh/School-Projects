# %%
import csv 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import pandas as pd

# %%
sns.set('talk')

# %%
with open('life-expectancy-vs-gdp-per-capita.csv',newline='') as f:         #Ouverture du fichier CSV
    tableau=[]
    lire=csv.reader(f)                            #chargement des lignes du fichier csv
    print('',end='\n')
    print('Affichage des lignes du tableau',end='\n')
    for ligne in lire:                            #Pour chaque ligne... 
        #print(ligne, end='\n')                    #...affichage de la ligne dans la console ...
        tableau.append(ligne)                     #...on ajoute la ligne dans la liste ...
tableau
# Out:
# Affichage des lignes du tableau
# [['Entity',
#   'Code',
#   'Year',
#   'Total population (Gapminder, HYDE & UN)',
#   'Continent',
#   'Life expectancy',
#   'Real GDP per capita in 2011US$, multiple benchmarks (Maddison Project Database (2018))'],
#  ['Abkhazia', 'OWID_ABK', '2015', '', 'Asia', '', ''],
#  ['Afghanistan', 'AFG', '1800', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1801', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1802', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1803', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1804', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1805', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1806', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1807', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1808', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1809', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1810', '3280000', '', '', ''],
#  ['Afghanistan', 'AFG', '1811', '3280779', '', '', ''],
#  ['Afghanistan', 'AFG', '1812', '3282342', '', '', ''],
#  ['Afghanistan', 'AFG', '1813', '3284692', '', '', ''],
#  ['Afghanistan', 'AFG', '1814', '3287834', '', '', ''],
#  ['Afghanistan', 'AFG', '1815', '3291770', '', '', ''],
#  ['Afghanistan', 'AFG', '1816', '3296506', '', '', ''],
#  ['Afghanistan', 'AFG', '1817', '3302044', '', '', ''],
#  ['Afghanistan', 'AFG', '1818', '3308390', '', '', ''],
#  ['Afghanistan', 'AFG', '1819', '3315547', '', '', ''],
#  ['Afghanistan', 'AFG', '1820', '3323519', '', '', ''],
#  ['Afghanistan', 'AFG', '1821', '3332311', '', '', ''],
#  ['Afghanistan', 'AFG', '1822', '3341926', '', '', ''],
#  ['Afghanistan', 'AFG', '1823', '3352368', '', '', ''],
#  ['Afghanistan', 'AFG', '1824', '3363642', '', '', ''],
#  ['Afghanistan', 'AFG', '1825', '3375751', '', '', ''],
#  ['Afghanistan', 'AFG', '1826', '3388701', '', '', ''],
#  ['Afghanistan', 'AFG', '1827', '3402494', '', '', ''],
#  ['Afghanistan', 'AFG', '1828', '3417136', '', '', ''],
#  ['Afghanistan', 'AFG', '1829', '3432630', '', '', ''],
#  ['Afghanistan', 'AFG', '1830', '3448982', '', '', ''],
#  ['Afghanistan', 'AFG', '1831', '3466194', '', '', ''],
#  ['Afghanistan', 'AFG', '1832', '3483492', '', '', ''],
#  ['Afghanistan', 'AFG', '1833', '3500877', '', '', ''],
#  ['Afghanistan', 'AFG', '1834', '3518348', '', '', ''],
#  ['Afghanistan', 'AFG', '1835', '3535906', '', '', ''],
#  ['Afghanistan', 'AFG', '1836', '3553552', '', '', ''],
#  ['Afghanistan', 'AFG', '1837', '3571286', '', '', ''],
#  ['Afghanistan', 'AFG', '1838', '3589109', '', '', ''],
#  ['Afghanistan', 'AFG', '1839', '3607021', '', '', ''],
#  ['Afghanistan', 'AFG', '1840', '3625022', '', '', ''],
#  ['Afghanistan', 'AFG', '1841', '3643112', '', '', ''],
#  ['Afghanistan', 'AFG', '1842', '3661294', '', '', ''],
#  ['Afghanistan', 'AFG', '1843', '3679565', '', '', ''],
#  ['Afghanistan', 'AFG', '1844', '3697928', '', '', ''],
#  ['Afghanistan', 'AFG', '1845', '3716383', '', '', ''],
#  ['Afghanistan', 'AFG', '1846', '3734930', '', '', ''],
#  ['Afghanistan', 'AFG', '1847', '3753569', '', '', ''],
#  ['Afghanistan', 'AFG', '1848', '3772301', '', '', ''],
#  ['Afghanistan', 'AFG', '1849', '3791127', '', '', ''],
#  ['Afghanistan', 'AFG', '1850', '3810047', '', '', ''],
#  ['Afghanistan', 'AFG', '1851', '3826140', '', '', ''],
#  ['Afghanistan', 'AFG', '1852', '3842299', '', '', ''],
#  ['Afghanistan', 'AFG', '1853', '3858524', '', '', ''],
#  ['Afghanistan', 'AFG', '1854', '3874815', '', '', ''],
#  ['Afghanistan', 'AFG', '1855', '3891173', '', '', ''],
#  ['Afghanistan', 'AFG', '1856', '3907598', '', '', ''],
#  ['Afghanistan', 'AFG', '1857', '3924089', '', '', ''],
#  ['Afghanistan', 'AFG', '1858', '3940648', '', '', ''],
#  ['Afghanistan', 'AFG', '1859', '3957274', '', '', ''],
#  ['Afghanistan', 'AFG', '1860', '3973968', '', '', ''],
#  ['Afghanistan', 'AFG', '1861', '3991172', '', '', ''],
#  ['Afghanistan', 'AFG', '1862', '4008889', '', '', ''],
#  ['Afghanistan', 'AFG', '1863', '4027125', '', '', ''],
#  ['Afghanistan', 'AFG', '1864', '4045883', '', '', ''],
#  ['Afghanistan', 'AFG', '1865', '4065170', '', '', ''],
#  ['Afghanistan', 'AFG', '1866', '4084989', '', '', ''],
#  ['Afghanistan', 'AFG', '1867', '4105346', '', '', ''],
#  ['Afghanistan', 'AFG', '1868', '4126245', '', '', ''],
#  ['Afghanistan', 'AFG', '1869', '4147692', '', '', ''],
#  ['Afghanistan', 'AFG', '1870', '4169690', '', '', ''],
#  ['Afghanistan', 'AFG', '1871', '4192245', '', '', ''],
#  ['Afghanistan', 'AFG', '1872', '4215362', '', '', ''],
#  ['Afghanistan', 'AFG', '1873', '4236341', '', '', ''],
#  ['Afghanistan', 'AFG', '1874', '4260730', '', '', ''],
#  ['Afghanistan', 'AFG', '1875', '4285744', '', '', ''],
#  ['Afghanistan', 'AFG', '1876', '4311388', '', '', ''],
#  ['Afghanistan', 'AFG', '1877', '4336107', '', '', ''],
#  ['Afghanistan', 'AFG', '1878', '4363439', '', '', ''],
#  ['Afghanistan', 'AFG', '1879', '4391478', '', '', ''],
#  ['Afghanistan', 'AFG', '1880', '4419695', '', '', ''],
#  ['Afghanistan', 'AFG', '1881', '4447479', '', '', ''],
#  ['Afghanistan', 'AFG', '1882', '4476050', '', '', ''],
#  ['Afghanistan', 'AFG', '1883', '4504802', '', '', ''],
#  ['Afghanistan', 'AFG', '1884', '4533190', '', '', ''],
#  ['Afghanistan', 'AFG', '1885', '4562304', '', '', ''],
#  ['Afghanistan', 'AFG', '1886', '4591602', '', '', ''],
#  ['Afghanistan', 'AFG', '1887', '4620608', '', '', ''],
#  ['Afghanistan', 'AFG', '1888', '4650274', '', '', ''],
#  ['Afghanistan', 'AFG', '1889', '4680128', '', '', ''],
#  ['Afghanistan', 'AFG', '1890', '4710171', '', '', ''],
#  ['Afghanistan', 'AFG', '1891', '4740404', '', '', ''],
#  ['Afghanistan', 'AFG', '1892', '4770828', '', '', ''],
#  ['Afghanistan', 'AFG', '1893', '4801444', '', '', ''],
#  ['Afghanistan', 'AFG', '1894', '4832253', '', '', ''],
#  ['Afghanistan', 'AFG', '1895', '4863258', '', '', ''],
#  ['Afghanistan', 'AFG', '1896', '4894458', '', '', ''],
#  ['Afghanistan', 'AFG', '1897', '4925855', '', '', ''],
#  ['Afghanistan', 'AFG', '1898', '4957450', '', '', ''],
#  ['Afghanistan', 'AFG', '1899', '4989245', '', '', ''],
#  ['Afghanistan', 'AFG', '1900', '5021241', '', '', ''],
#  ['Afghanistan', 'AFG', '1901', '5053439', '', '', ''],
#  ['Afghanistan', 'AFG', '1902', '5085403', '', '', ''],
#  ['Afghanistan', 'AFG', '1903', '5118005', '', '', ''],
#  ['Afghanistan', 'AFG', '1904', '5150814', '', '', ''],
#  ['Afghanistan', 'AFG', '1905', '5183829', '', '', ''],
#  ['Afghanistan', 'AFG', '1906', '5217053', '', '', ''],
#  ['Afghanistan', 'AFG', '1907', '5249854', '', '', ''],
#  ['Afghanistan', 'AFG', '1908', '5283495', '', '', ''],
#  ['Afghanistan', 'AFG', '1909', '5317347', '', '', ''],
#  ['Afghanistan', 'AFG', '1910', '5351413', '', '', ''],
#  ['Afghanistan', 'AFG', '1911', '5385509', '', '', ''],
#  ['Afghanistan', 'AFG', '1912', '5420004', '', '', ''],
#  ['Afghanistan', 'AFG', '1913', '5459010', '', '', ''],
#  ['Afghanistan', 'AFG', '1914', '5502589', '', '', ''],
#  ['Afghanistan', 'AFG', '1915', '5550805', '', '', ''],
#  ['Afghanistan', 'AFG', '1916', '5599440', '', '', ''],
#  ['Afghanistan', 'AFG', '1917', '5648497', '', '', ''],
#  ['Afghanistan', 'AFG', '1918', '5704092', '', '', ''],
#  ['Afghanistan', 'AFG', '1919', '5758692', '', '', ''],
#  ['Afghanistan', 'AFG', '1920', '5813814', '', '', ''],
#  ['Afghanistan', 'AFG', '1921', '5869464', '', '', ''],
#  ['Afghanistan', 'AFG', '1922', '5925647', '', '', ''],
#  ['Afghanistan', 'AFG', '1923', '5982368', '', '', ''],
#  ['Afghanistan', 'AFG', '1924', '6039631', '', '', ''],
#  ['Afghanistan', 'AFG', '1925', '6097443', '', '', ''],
#  ['Afghanistan', 'AFG', '1926', '6155808', '', '', ''],
#  ['Afghanistan', 'AFG', '1927', '6214731', '', '', ''],
#  ['Afghanistan', 'AFG', '1928', '6274219', '', '', ''],
#  ['Afghanistan', 'AFG', '1929', '6334276', '', '', ''],
#  ['Afghanistan', 'AFG', '1930', '6394908', '', '', ''],
#  ['Afghanistan', 'AFG', '1931', '6456120', '', '', ''],
#  ['Afghanistan', 'AFG', '1932', '6517918', '', '', ''],
#  ['Afghanistan', 'AFG', '1933', '6580308', '', '', ''],
#  ['Afghanistan', 'AFG', '1934', '6643295', '', '', ''],
#  ['Afghanistan', 'AFG', '1935', '6706885', '', '', ''],
#  ['Afghanistan', 'AFG', '1936', '6771083', '', '', ''],
#  ['Afghanistan', 'AFG', '1937', '6835896', '', '', ''],
#  ['Afghanistan', 'AFG', '1938', '6901330', '', '', ''],
#  ['Afghanistan', 'AFG', '1939', '6967389', '', '', ''],
#  ['Afghanistan', 'AFG', '1940', '7034081', '', '', ''],
#  ['Afghanistan', 'AFG', '1941', '7101412', '', '', ''],
#  ['Afghanistan', 'AFG', '1942', '7169387', '', '', ''],
#  ['Afghanistan', 'AFG', '1943', '7238012', '', '', ''],
#  ['Afghanistan', 'AFG', '1944', '7307295', '', '', ''],
#  ['Afghanistan', 'AFG', '1945', '7377241', '', '', ''],
#  ['Afghanistan', 'AFG', '1946', '7447856', '', '', ''],
#  ['Afghanistan', 'AFG', '1947', '7519147', '', '', ''],
#  ['Afghanistan', 'AFG', '1948', '7591120', '', '', ''],
#  ['Afghanistan', 'AFG', '1949', '7663783', '', '', ''],
#  ['Afghanistan', 'AFG', '1950', '7752000', '', '27.638', '2392'],
#  ['Afghanistan', 'AFG', '1951', '7840000', '', '27.878', '2422'],
#  ['Afghanistan', 'AFG', '1952', '7936000', '', '28.361', '2462'],
#  ['Afghanistan', 'AFG', '1953', '8040000', '', '28.852', '2568'],
#  ['Afghanistan', 'AFG', '1954', '8151000', '', '29.35', '2576'],
#  ['Afghanistan', 'AFG', '1955', '8271000', '', '29.854', '2579'],
#  ['Afghanistan', 'AFG', '1956', '8399000', '', '30.365', '2644'],
#  ['Afghanistan', 'AFG', '1957', '8535000', '', '30.882', '2593'],
#  ['Afghanistan', 'AFG', '1958', '8680000', '', '31.403', '2684'],
#  ['Afghanistan', 'AFG', '1959', '8834000', '', '31.925', '2705'],
#  ['Afghanistan', 'AFG', '1960', '8997000', '', '32.446', '2744'],
#  ['Afghanistan', 'AFG', '1961', '9169000', '', '32.962', '2708'],
#  ['Afghanistan', 'AFG', '1962', '9351000', '', '33.471', '2695'],
#  ['Afghanistan', 'AFG', '1963', '9543000', '', '33.971', '2683'],
#  ['Afghanistan', 'AFG', '1964', '9745000', '', '34.463', '2673'],
#  ['Afghanistan', 'AFG', '1965', '9956000', '', '34.948', '2670'],
#  ['Afghanistan', 'AFG', '1966', '10175000', '', '35.43', '2633'],
#  ['Afghanistan', 'AFG', '1967', '10400000', '', '35.914', '2642'],
#  ['Afghanistan', 'AFG', '1968', '10637000', '', '36.403', '2670'],
#  ['Afghanistan', 'AFG', '1969', '10894000', '', '36.9', '2646'],
#  ['Afghanistan', 'AFG', '1970', '11174000', '', '37.409', '2632'],
#  ['Afghanistan', 'AFG', '1971', '11475000', '', '37.93', '2560'],
#  ['Afghanistan', 'AFG', '1972', '11791000', '', '38.461', '2086'],
#  ['Afghanistan', 'AFG', '1973', '12109000', '', '39.003', '2091'],
#  ['Afghanistan', 'AFG', '1974', '12413000', '', '39.558', '2149'],
#  ['Afghanistan', 'AFG', '1975', '12689000', '', '40.128', '2225'],
#  ['Afghanistan', 'AFG', '1976', '12943000', '', '40.715', '2286'],
#  ['Afghanistan', 'AFG', '1977', '13171000', '', '41.32', '2116'],
#  ['Afghanistan', 'AFG', '1978', '13341000', '', '41.944', '2215'],
#  ['Afghanistan', 'AFG', '1979', '13411000', '', '42.585', '2118'],
#  ['Afghanistan', 'AFG', '1980', '13357000', '', '43.244', '2108'],
#  ['Afghanistan', 'AFG', '1981', '13172000', '', '43.923', '2369'],
#  ['Afghanistan', 'AFG', '1982', '12883000', '', '44.617', '2628'],
#  ['Afghanistan', 'AFG', '1983', '12538000', '', '45.324', '2789'],
#  ['Afghanistan', 'AFG', '1984', '12204000', '', '46.04', '2766'],
#  ['Afghanistan', 'AFG', '1985', '11938000', '', '46.761', '2700'],
#  ['Afghanistan', 'AFG', '1986', '11736000', '', '47.486', '2779'],
#  ['Afghanistan', 'AFG', '1987', '11605000', '', '48.211', '2507'],
#  ['Afghanistan', 'AFG', '1988', '11618000', '', '48.93', '2280'],
#  ['Afghanistan', 'AFG', '1989', '11869000', '', '49.64', '2067'],
#  ['Afghanistan', 'AFG', '1990', '12412000', '', '50.331', '1992'],
#  ['Afghanistan', 'AFG', '1991', '13299000', '', '50.999', '1761'],
#  ['Afghanistan', 'AFG', '1992', '14486000', '', '51.641', '1629'],
#  ['Afghanistan', 'AFG', '1993', '15817000', '', '52.256', '1080'],
#  ['Afghanistan', 'AFG', '1994', '17076000', '', '52.842', '772'],
#  ['Afghanistan', 'AFG', '1995', '18111000', '', '53.398', '1101'],
#  ['Afghanistan', 'AFG', '1996', '18853000', '', '53.924', '1008'],
#  ['Afghanistan', 'AFG', '1997', '19357000', '', '54.424', '926'],
#  ['Afghanistan', 'AFG', '1998', '19738000', '', '54.906', '856'],
#  ['Afghanistan', 'AFG', '1999', '20171000', '', '55.376', '787'],
#  ['Afghanistan', 'AFG', '2000', '20780000', '', '55.841', '735'],
#  ['Afghanistan', 'AFG', '2001', '21607000', '', '56.308', '692'],
#  ['Afghanistan', 'AFG', '2002', '22601000', '', '56.784', '1088'],
#  ['Afghanistan', 'AFG', '2003', '23681000', '', '57.271', '1112'],
#  ['Afghanistan', 'AFG', '2004', '24727000', '', '57.772', '1107'],
#  ['Afghanistan', 'AFG', '2005', '25654000', '', '58.29', '1187'],
#  ['Afghanistan', 'AFG', '2006', '26433000', '', '58.826', '1257'],
#  ['Afghanistan', 'AFG', '2007', '27101000', '', '59.375', '1447'],
#  ['Afghanistan', 'AFG', '2008', '27722000', '', '59.93', '1464'],
#  ['Afghanistan', 'AFG', '2009', '28395000', '', '60.484', '1669'],
#  ['Afghanistan', 'AFG', '2010', '29186000', '', '61.028', '1685'],
#  ['Afghanistan', 'AFG', '2011', '30117000', '', '61.553', '1792'],
#  ['Afghanistan', 'AFG', '2012', '31161000', '', '62.054', '1945'],
#  ['Afghanistan', 'AFG', '2013', '32270000', '', '62.525', '2025'],
#  ['Afghanistan', 'AFG', '2014', '33371000', '', '62.966', '2022'],
#  ['Afghanistan', 'AFG', '2015', '34414000', 'Asia', '63.377', '1928'],
#  ['Afghanistan', 'AFG', '2016', '35383000', '', '63.763', '1929'],
#  ['Afghanistan', 'AFG', '2017', '36296000', '', '64.13', ''],
#  ['Afghanistan', 'AFG', '2018', '37172000', '', '64.486', ''],
#  ['Afghanistan', 'AFG', '2019', '38042000', '', '64.833', ''],
#  ['Africa', '', '-10000', '241901', '', '', ''],
#  ['Africa', '', '-9000', '342782', '', '', ''],
#  ['Africa', '', '-8000', '490284', '', '', ''],
#  ['Africa', '', '-7000', '707844', '', '', ''],
#  ['Africa', '', '-6000', '1031529', '', '', ''],
#  ['Africa', '', '-5000', '1517227', '', '', ''],
#  ['Africa', '', '-4000', '2352091', '', '', ''],
#  ['Africa', '', '-3000', '4147835', '', '', ''],
#  ['Africa', '', '-2000', '6259743', '', '', ''],
#  ['Africa', '', '-1000', '9263872', '', '', ''],
#  ['Africa', '', '0', '15185668', '', '', ''],
#  ['Africa', '', '100', '16626739', '', '', ''],
#  ['Africa', '', '200', '18269986', '', '', ''],
#  ['Africa', '', '300', '19315228', '', '', ''],
#  ['Africa', '', '400', '20676600', '', '', ''],
#  ['Africa', '', '500', '22307212', '', '', ''],
#  ['Africa', '', '600', '24445556', '', '', ''],
#  ['Africa', '', '700', '28184552', '', '', ''],
#  ['Africa', '', '800', '32914604', '', '', ''],
#  ['Africa', '', '900', '37126288', '', '', ''],
#  ['Africa', '', '1000', '41465160', '', '', ''],
#  ['Africa', '', '1100', '44318856', '', '', ''],
#  ['Africa', '', '1200', '47743012', '', '', ''],
#  ['Africa', '', '1300', '53531812', '', '', ''],
#  ['Africa', '', '1400', '57880048', '', '', ''],
#  ['Africa', '', '1500', '62206640', '', '', ''],
#  ['Africa', '', '1600', '72815088', '', '', ''],
#  ['Africa', '', '1700', '80209440', '', '', ''],
#  ['Africa', '', '1710', '81333552', '', '', ''],
#  ['Africa', '', '1720', '81582976', '', '', ''],
#  ['Africa', '', '1730', '81891216', '', '', ''],
#  ['Africa', '', '1740', '82256496', '', '', ''],
#  ['Africa', '', '1750', '82677328', '', '', ''],
#  ['Africa', '', '1760', '83152512', '', '', ''],
#  ['Africa', '', '1770', '83681184', '', '26.4', ''],
#  ['Africa', '', '1780', '84262792', '', '', ''],
#  ['Africa', '', '1790', '84900352', '', '', ''],
#  ['Africa', '', '1800', '85589224', '', '', ''],
#  ['Africa', '', '1810', '86829040', '', '', ''],
#  ['Africa', '', '1820', '89179576', '', '', ''],
#  ['Africa', '', '1830', '93551648', '', '', ''],
#  ['Africa', '', '1840', '98188272', '', '', ''],
#  ['Africa', '', '1850', '102932088', '', '', ''],
#  ['Africa', '', '1860', '107457472', '', '', ''],
#  ['Africa', '', '1870', '114300952', '', '', ''],
#  ['Africa', '', '1880', '122176248', '', '', ''],
#  ['Africa', '', '1890', '131305600', '', '', ''],
#  ['Africa', '', '1900', '140754896', '', '', ''],
#  ['Africa', '', '1910', '150280992', '', '', ''],
#  ['Africa', '', '1920', '164856080', '', '', ''],
#  ['Africa', '', '1925', '', '', '26.4', ''],
#  ['Africa', '', '1930', '181280496', '', '', ''],
#  ['Africa', '', '1940', '200894592', '', '', ''],
#  ['Africa', '', '1950', '227794000', '', '36.45', '1596'],
#  ['Africa', '', '1951', '232328000', '', '36.712', '1606'],
#  ['Africa', '', '1952', '237096992', '', '37.234', '1618'],
#  ['Africa', '', '1953', '242092000', '', '37.754', '1658'],
#  ['Africa', '', '1954', '247311008', '', '38.27', '1717'],
#  ['Africa', '', '1955', '252748992', '', '38.783', '1748'],
#  ['Africa', '', '1956', '258408000', '', '39.293', '1762'],
#  ['Africa', '', '1957', '264292000', '', '39.799', '1794'],
#  ['Africa', '', '1958', '270407008', '', '40.299', '1786'],
#  ['Africa', '', '1959', '276760992', '', '40.793', '1840'],
#  ['Africa', '', '1960', '283360992', '', '41.277', '1852'],
#  ['Africa', '', '1961', '290214016', '', '41.75', '1883'],
#  ['Africa', '', '1962', '297323008', '', '42.211', '1971'],
#  ['Africa', '', '1963', '304683008', '', '42.657', '2053'],
#  ['Africa', '', '1964', '312292000', '', '43.091', '2117'],
#  ['Africa', '', '1965', '320147008', '', '43.513', '2251'],
#  ['Africa', '', '1966', '328256992', '', '43.927', '2256'],
#  ['Africa', '', '1967', '336631008', '', '44.335', '2225'],
#  ['Africa', '', '1968', '345280000', '', '44.742', '2306'],
#  ['Africa', '', '1969', '354215008', '', '45.15', '2556'],
#  ['Africa', '', '1970', '363448000', '', '45.563', '2963'],
#  ['Africa', '', '1971', '372984000', '', '45.984', '3023'],
#  ['Africa', '', '1972', '382838016', '', '46.414', '3082'],
#  ['Africa', '', '1973', '393044000', '', '46.85', '3238'],
#  ['Africa', '', '1974', '403646016', '', '47.29', '3525'],
#  ['Africa', '', '1975', '414675008', '', '47.733', '3523'],
#  ['Africa', '', '1976', '426144000', '', '48.175', '3629'],
#  ['Africa', '', '1977', '438055008', '', '48.612', '3772'],
#  ['Africa', '', '1978', '450404000', '', '49.04', '3781'],
#  ['Africa', '', '1979', '463184000', '', '49.452', '3852'],
#  ['Africa', '', '1980', '476385984', '', '49.851', '3862'],
#  ['Africa', '', '1981', '490004000', '', '50.235', '3697'],
#  ['Africa', '', '1982', '504033984', '', '50.606', '3721'],
#  ['Africa', '', '1983', '518480000', '', '50.959', '3656'],
#  ['Africa', '', '1984', '533344992', '', '51.286', '3547'],
#  ['Africa', '', '1985', '548625984', '', '51.571', '3620'],
#  ['Africa', '', '1986', '564326976', '', '51.798', '3395'],
#  ['Africa', '', '1987', '580424000', '', '51.959', '3245'],
#  ['Africa', '', '1988', '596849024', '', '52.054', '3249'],
#  ['Africa', '', '1989', '613512000', '', '52.092', '3230'],
#  ['Africa', '', '1990', '630350016', '', '52.083', '3170'],
#  ['Africa', '', '1991', '647344000', '', '52.047', '3068'],
#  ['Africa', '', '1992', '664512000', '', '52.005', '3011'],
#  ['Africa', '', '1993', '681868992', '', '51.978', '2902'],
#  ['Africa', '', '1994', '699444992', '', '51.982', '2870'],
#  ['Africa', '', '1995', '717270016', '', '52.022', '2869'],
#  ['Africa', '', '1996', '735361024', '', '52.095', '2934'],
#  ['Africa', '', '1997', '753737984', '', '52.195', '2913'],
#  ['Africa', '', '1998', '772436992', '', '52.323', '2875'],
#  ['Africa', '', '1999', '791504000', '', '52.487', '2858'],
#  ['Africa', '', '2000', '810984000', '', '52.705', '2889'],
#  ['Africa', '', '2001', '830902976', '', '52.995', '2919'],
#  ['Africa', '', '2002', '851297984', '', '53.368', '2980'],
#  ['Africa', '', '2003', '872248000', '', '53.827', '3045'],
#  ['Africa', '', '2004', '893843008', '', '54.367', '3140'],
#  ['Africa', '', '2005', '916153984', '', '54.982', '3320'],
#  ['Africa', '', '2006', '939209984', '', '55.661', '3494'],
#  ['Africa', '', '2007', '963022016', '', '56.382', '3790'],
#  ['Africa', '', '2008', '987624000', '', '57.121', '4016'],
#  ['Africa', '', '2009', '1013046016', '', '57.858', '3998'],
#  ['Africa', '', '2010', '1039304000', '', '58.576', '4340'],
#  ['Africa', '', '2011', '1066409984', '', '59.263', '4487'],
#  ['Africa', '', '2012', '1094343040', '', '59.914', '4614'],
#  ['Africa', '', '2013', '1123044992', '', '60.527', '4577'],
#  ['Africa', '', '2014', '1152434048', '', '61.093', '4638'],
#  ['Africa', '', '2015', '1182439040', '', '61.607', '4684'],
#  ['Africa', '', '2016', '1213041024', '', '62.064', '4680'],
#  ['Africa', '', '2017', '1244221952', '', '62.472', ''],
#  ['Africa', '', '2018', '1275921024', '', '62.839', ''],
#  ['Africa', '', '2019', '1308064000', '', '63.17', ''],
#  ['Akrotiri and Dhekelia', 'OWID_AKD', '2015', '', 'Asia', '', ''],
#  ['Albania', 'ALB', '1800', '410445', '', '', ''],
#  ['Albania', 'ALB', '1801', '411734', '', '', ''],
#  ['Albania', 'ALB', '1802', '413026', '', '', ''],
#  ['Albania', 'ALB', '1803', '414323', '', '', ''],
#  ['Albania', 'ALB', '1804', '415624', '', '', ''],
#  ['Albania', 'ALB', '1805', '416929', '', '', ''],
#  ['Albania', 'ALB', '1806', '418237', '', '', ''],
#  ['Albania', 'ALB', '1807', '419550', '', '', ''],
#  ['Albania', 'ALB', '1808', '420868', '', '', ''],
#  ['Albania', 'ALB', '1809', '422189', '', '', ''],
#  ['Albania', 'ALB', '1810', '423591', '', '', ''],
#  ['Albania', 'ALB', '1811', '424949', '', '', ''],
#  ['Albania', 'ALB', '1812', '426340', '', '', ''],
#  ['Albania', 'ALB', '1813', '427763', '', '', ''],
#  ['Albania', 'ALB', '1814', '429220', '', '', ''],
#  ['Albania', 'ALB', '1815', '430711', '', '', ''],
#  ['Albania', 'ALB', '1816', '432235', '', '', ''],
#  ['Albania', 'ALB', '1817', '433792', '', '', ''],
#  ['Albania', 'ALB', '1818', '435384', '', '', ''],
#  ['Albania', 'ALB', '1819', '437010', '', '', ''],
#  ['Albania', 'ALB', '1820', '438671', '', '', ''],
#  ['Albania', 'ALB', '1821', '440367', '', '', ''],
#  ['Albania', 'ALB', '1822', '442097', '', '', ''],
#  ['Albania', 'ALB', '1823', '443863', '', '', ''],
#  ['Albania', 'ALB', '1824', '445665', '', '', ''],
#  ['Albania', 'ALB', '1825', '447502', '', '', ''],
#  ['Albania', 'ALB', '1826', '449375', '', '', ''],
#  ['Albania', 'ALB', '1827', '451285', '', '', ''],
#  ['Albania', 'ALB', '1828', '453231', '', '', ''],
#  ['Albania', 'ALB', '1829', '455214', '', '', ''],
#  ['Albania', 'ALB', '1830', '457234', '', '', ''],
#  ['Albania', 'ALB', '1831', '459291', '', '', ''],
#  ['Albania', 'ALB', '1832', '461357', '', '', ''],
#  ['Albania', 'ALB', '1833', '463433', '', '', ''],
#  ['Albania', 'ALB', '1834', '465518', '', '', ''],
#  ['Albania', 'ALB', '1835', '467613', '', '', ''],
#  ['Albania', 'ALB', '1836', '469716', '', '', ''],
#  ['Albania', 'ALB', '1837', '471830', '', '', ''],
#  ['Albania', 'ALB', '1838', '473953', '', '', ''],
#  ['Albania', 'ALB', '1839', '476085', '', '', ''],
#  ['Albania', 'ALB', '1840', '478227', '', '', ''],
#  ['Albania', 'ALB', '1841', '480496', '', '', ''],
#  ['Albania', 'ALB', '1842', '482893', '', '', ''],
#  ['Albania', 'ALB', '1843', '485419', '', '', ''],
#  ['Albania', 'ALB', '1844', '488078', '', '', ''],
#  ['Albania', 'ALB', '1845', '490869', '', '', ''],
#  ['Albania', 'ALB', '1846', '493796', '', '', ''],
#  ['Albania', 'ALB', '1847', '496859', '', '', ''],
#  ['Albania', 'ALB', '1848', '500062', '', '', ''],
#  ['Albania', 'ALB', '1849', '503404', '', '', ''],
#  ['Albania', 'ALB', '1850', '506889', '', '', ''],
#  ['Albania', 'ALB', '1851', '510780', '', '', ''],
#  ['Albania', 'ALB', '1852', '514821', '', '', ''],
#  ['Albania', 'ALB', '1853', '519014', '', '', ''],
#  ['Albania', 'ALB', '1854', '523361', '', '', ''],
#  ['Albania', 'ALB', '1855', '527865', '', '', ''],
#  ['Albania', 'ALB', '1856', '532526', '', '', ''],
#  ['Albania', 'ALB', '1857', '537348', '', '', ''],
#  ['Albania', 'ALB', '1858', '542333', '', '', ''],
#  ['Albania', 'ALB', '1859', '547483', '', '', ''],
#  ['Albania', 'ALB', '1860', '552800', '', '', ''],
#  ['Albania', 'ALB', '1861', '558285', '', '', ''],
#  ['Albania', 'ALB', '1862', '563821', '', '', ''],
#  ['Albania', 'ALB', '1863', '569410', '', '', ''],
#  ['Albania', 'ALB', '1864', '575051', '', '', ''],
#  ['Albania', 'ALB', '1865', '580746', '', '', ''],
#  ['Albania', 'ALB', '1866', '586494', '', '', ''],
#  ['Albania', 'ALB', '1867', '592297', '', '', ''],
#  ['Albania', 'ALB', '1868', '598154', '', '', ''],
#  ['Albania', 'ALB', '1869', '604067', '', '', ''],
#  ['Albania', 'ALB', '1870', '610036', '', '', '658'],
#  ['Albania', 'ALB', '1871', '616061', '', '', ''],
#  ['Albania', 'ALB', '1872', '622143', '', '', ''],
#  ['Albania', 'ALB', '1873', '628113', '', '', ''],
#  ['Albania', 'ALB', '1874', '634308', '', '', ''],
#  ['Albania', 'ALB', '1875', '640561', '', '', ''],
#  ['Albania', 'ALB', '1876', '646873', '', '', ''],
#  ['Albania', 'ALB', '1877', '653080', '', '', ''],
#  ['Albania', 'ALB', '1878', '659507', '', '', ''],
#  ['Albania', 'ALB', '1879', '665994', '', '', ''],
#  ['Albania', 'ALB', '1880', '672545', '', '', ''],
#  ['Albania', 'ALB', '1881', '679004', '', '', ''],
#  ['Albania', 'ALB', '1882', '685682', '', '', ''],
#  ['Albania', 'ALB', '1883', '692426', '', '', ''],
#  ['Albania', 'ALB', '1884', '699096', '', '', ''],
#  ['Albania', 'ALB', '1885', '705996', '', '', ''],
#  ['Albania', 'ALB', '1886', '712988', '', '', ''],
#  ['Albania', 'ALB', '1887', '719888', '', '', ''],
#  ['Albania', 'ALB', '1888', '727055', '', '', ''],
#  ['Albania', 'ALB', '1889', '734321', '', '', ''],
#  ['Albania', 'ALB', '1890', '741690', '', '', '882'],
#  ['Albania', 'ALB', '1891', '749160', '', '', ''],
#  ['Albania', 'ALB', '1892', '756735', '', '', ''],
#  ['Albania', 'ALB', '1893', '764415', '', '', ''],
#  ['Albania', 'ALB', '1894', '772202', '', '', ''],
#  ['Albania', 'ALB', '1895', '780097', '', '', ''],
#  ['Albania', 'ALB', '1896', '788036', '', '', ''],
#  ['Albania', 'ALB', '1897', '795992', '', '', ''],
#  ['Albania', 'ALB', '1898', '803964', '', '', ''],
#  ['Albania', 'ALB', '1899', '811950', '', '', ''],
#  ['Albania', 'ALB', '1900', '819951', '', '', '1011'],
#  ['Albania', 'ALB', '1901', '827966', '', '', ''],
#  ['Albania', 'ALB', '1902', '836031', '', '', ''],
#  ['Albania', 'ALB', '1903', '844038', '', '', ''],
#  ['Albania', 'ALB', '1904', '852043', '', '', ''],
#  ['Albania', 'ALB', '1905', '860044', '', '', ''],
#  ['Albania', 'ALB', '1906', '868121', '', '', ''],
#  ['Albania', 'ALB', '1907', '876112', '', '', ''],
#  ['Albania', 'ALB', '1908', '884339', '', '', ''],
#  ['Albania', 'ALB', '1909', '892676', '', '', ''],
#  ['Albania', 'ALB', '1910', '901124', '', '', '1152'],
#  ['Albania', 'ALB', '1911', '909604', '', '', ''],
#  ['Albania', 'ALB', '1912', '918312', '', '', ''],
#  ['Albania', 'ALB', '1913', '925945', '', '', '1197'],
#  ['Albania', 'ALB', '1914', '932486', '', '', ''],
#  ['Albania', 'ALB', '1915', '937916', '', '', ''],
#  ['Albania', 'ALB', '1916', '943378', '', '', ''],
#  ['Albania', 'ALB', '1917', '948871', '', '', ''],
#  ['Albania', 'ALB', '1918', '953764', '', '', ''],
#  ['Albania', 'ALB', '1919', '958841', '', '', ''],
#  ['Albania', 'ALB', '1920', '963958', '', '', ''],
#  ['Albania', 'ALB', '1921', '969107', '', '', ''],
#  ['Albania', 'ALB', '1922', '974278', '', '', ''],
#  ['Albania', 'ALB', '1923', '979450', '', '', ''],
#  ['Albania', 'ALB', '1924', '984276', '', '', ''],
#  ['Albania', 'ALB', '1925', '989448', '', '', ''],
#  ['Albania', 'ALB', '1926', '994619', '', '', ''],
#  ['Albania', 'ALB', '1927', '1000135', '', '', ''],
#  ['Albania', 'ALB', '1928', '1005306', '', '', ''],
#  ['Albania', 'ALB', '1929', '1010478', '', '', '1367'],
#  ['Albania', 'ALB', '1930', '1015994', '', '', ''],
#  ['Albania', 'ALB', '1931', '1021510', '', '', ''],
#  ['Albania', 'ALB', '1932', '1027026', '', '', ''],
#  ['Albania', 'ALB', '1933', '1032197', '', '', ''],
#  ['Albania', 'ALB', '1934', '1037713', '', '', ''],
#  ['Albania', 'ALB', '1935', '1043229', '', '', ''],
#  ['Albania', 'ALB', '1936', '1052538', '', '', ''],
#  ['Albania', 'ALB', '1937', '1063225', '', '', ''],
#  ['Albania', 'ALB', '1938', '1082532', '', '', ''],
#  ['Albania', 'ALB', '1939', '1102527', '', '', ''],
#  ['Albania', 'ALB', '1940', '1123213', '', '', ''],
#  ['Albania', 'ALB', '1941', '1139416', '', '', ''],
#  ['Albania', 'ALB', '1942', '1150104', '', '', ''],
#  ['Albania', 'ALB', '1943', '1157688', '', '', ''],
#  ['Albania', 'ALB', '1944', '1164928', '', '', ''],
#  ['Albania', 'ALB', '1945', '1176994', '', '', ''],
#  ['Albania', 'ALB', '1946', '1195267', '', '', ''],
#  ['Albania', 'ALB', '1947', '1213883', '', '', ''],
#  ['Albania', 'ALB', '1948', '1232845', '', '', ''],
#  ['Albania', 'ALB', '1949', '1246636', '', '', ''],
#  ['Albania', 'ALB', '1950', '1263000', '', '54.191', '1478'],
#  ['Albania', 'ALB', '1951', '1287000', '', '54.399', '1542'],
#  ['Albania', 'ALB', '1952', '1316000', '', '54.875', '1544'],
#  ['Albania', 'ALB', '1953', '1348000', '', '55.468', '1607'],
#  ['Albania', 'ALB', '1954', '1383000', '', '56.18', '1654'],
#  ['Albania', 'ALB', '1955', '1420000', '', '57.007', '1743'],
#  ['Albania', 'ALB', '1956', '1459000', '', '57.941', '1761'],
#  ['Albania', 'ALB', '1957', '1500000', '', '58.969', '1873'],
#  ['Albania', 'ALB', '1958', '1543000', '', '60.065', '1958'],
#  ['Albania', 'ALB', '1959', '1589000', '', '61.186', '2038'],
#  ['Albania', 'ALB', '1960', '1636000', '', '62.283', '2142'],
#  ['Albania', 'ALB', '1961', '1686000', '', '63.301', '2159'],
#  ['Albania', 'ALB', '1962', '1738000', '', '64.19', '2231'],
#  ['Albania', 'ALB', '1963', '1791000', '', '64.914', '2307'],
#  ['Albania', 'ALB', '1964', '1844000', '', '65.463', '2386'],
#  ['Albania', 'ALB', '1965', '1896000', '', '65.85', '2473'],
#  ['Albania', 'ALB', '1966', '1948000', '', '66.11', '2566'],
#  ['Albania', 'ALB', '1967', '1999000', '', '66.304', '2662'],
#  ['Albania', 'ALB', '1968', '2049000', '', '66.487', '2759'],
#  ['Albania', 'ALB', '1969', '2100000', '', '66.689', '2852'],
#  ['Albania', 'ALB', '1970', '2151000', '', '66.935', '2957'],
#  ['Albania', 'ALB', '1971', '2202000', '', '67.237', '3064'],
#  ['Albania', 'ALB', '1972', '2254000', '', '67.582', '3177'],
#  ['Albania', 'ALB', '1973', '2306000', '', '67.953', '3312'],
#  ['Albania', 'ALB', '1974', '2359000', '', '68.343', '3347'],
#  ['Albania', 'ALB', '1975', '2412000', '', '68.736', '3363'],
#  ['Albania', 'ALB', '1976', '2465000', '', '69.11', '3345'],
#  ['Albania', 'ALB', '1977', '2519000', '', '69.448', '3380'],
#  ['Albania', 'ALB', '1978', '2573000', '', '69.742', '3394'],
#  ['Albania', 'ALB', '1979', '2628000', '', '69.991', '3363'],
#  ['Albania', 'ALB', '1980', '2683000', '', '70.208', '3501'],
#  ['Albania', 'ALB', '1981', '2737000', '', '70.416', '3445'],
#  ['Albania', 'ALB', '1982', '2790000', '', '70.635', '3380'],
#  ['Albania', 'ALB', '1983', '2845000', '', '70.876', '3484'],
#  ['Albania', 'ALB', '1984', '2904000', '', '71.134', '3588'],
#  ['Albania', 'ALB', '1985', '2970000', '', '71.388', '3593'],
#  ['Albania', 'ALB', '1986', '3044000', '', '71.605', '3583'],
#  ['Albania', 'ALB', '1987', '3125000', '', '71.76', '3710'],
#  ['Albania', 'ALB', '1988', '3201000', '', '71.843', '3714'],
#  ['Albania', 'ALB', '1989', '3258000', '', '71.86', '3687'],
#  ['Albania', 'ALB', '1990', '3286000', '', '71.836', '4099'],
#  ['Albania', 'ALB', '1991', '3280000', '', '71.803', '3799'],
#  ['Albania', 'ALB', '1992', '3246000', '', '71.802', '3520'],
#  ['Albania', 'ALB', '1993', '3195000', '', '71.86', '4054'],
#  ['Albania', 'ALB', '1994', '3147000', '', '71.992', '4551'],
#  ['Albania', 'ALB', '1995', '3113000', '', '72.205', '4685'],
#  ['Albania', 'ALB', '1996', '3099000', '', '72.495', '5474'],
#  ['Albania', 'ALB', '1997', '3100000', '', '72.838', '4406'],
#  ['Albania', 'ALB', '1998', '3111000', '', '73.208', '4355'],
#  ['Albania', 'ALB', '1999', '3123000', '', '73.587', '5016'],
#  ['Albania', 'ALB', '2000', '3129000', '', '73.955', '5183'],
#  ['Albania', 'ALB', '2001', '3130000', '', '74.288', '5409'],
#  ['Albania', 'ALB', '2002', '3126000', '', '74.579', '5489'],
#  ['Albania', 'ALB', '2003', '3118000', '', '74.828', '5804'],
#  ['Albania', 'ALB', '2004', '3105000', '', '75.039', '6094'],
#  ['Albania', 'ALB', '2005', '3087000', '', '75.228', '6499'],
#  ['Albania', 'ALB', '2006', '3063000', '', '75.423', '7111'],
#  ['Albania', 'ALB', '2007', '3034000', '', '75.646', '7673'],
#  ['Albania', 'ALB', '2008', '3003000', '', '75.912', '8617'],
#  ['Albania', 'ALB', '2009', '2973000', '', '76.221', '9373'],
#  ['Albania', 'ALB', '2010', '2948000', '', '76.562', '9324'],
#  ['Albania', 'ALB', '2011', '2929000', '', '76.914', '9484'],
#  ['Albania', 'ALB', '2012', '2914000', '', '77.252', '10344'],
#  ['Albania', 'ALB', '2013', '2904000', '', '77.554', '10138'],
#  ['Albania', 'ALB', '2014', '2896000', '', '77.813', '10703'],
#  ['Albania', 'ALB', '2015', '2891000', 'Europe', '78.025', '10947'],
#  ['Albania', 'ALB', '2016', '2886000', '', '78.194', '11285'],
#  ['Albania', 'ALB', '2017', '2884000', '', '78.333', ''],
#  ['Albania', 'ALB', '2018', '2883000', '', '78.458', ''],
#  ['Albania', 'ALB', '2019', '2881000', '', '78.573', ''],
#  ['Algeria', 'DZA', '1800', '2503218', '', '', ''],
#  ['Algeria', 'DZA', '1801', '2512195', '', '', ''],
#  ['Algeria', 'DZA', '1802', '2521203', '', '', ''],
#  ['Algeria', 'DZA', '1803', '2530245', '', '', ''],
#  ['Algeria', 'DZA', '1804', '2539318', '', '', ''],
#  ['Algeria', 'DZA', '1805', '2548424', '', '', ''],
#  ['Algeria', 'DZA', '1806', '2557563', '', '', ''],
#  ['Algeria', 'DZA', '1807', '2566734', '', '', ''],
#  ['Algeria', 'DZA', '1808', '2575939', '', '', ''],
#  ['Algeria', 'DZA', '1809', '2585176', '', '', ''],
#  ['Algeria', 'DZA', '1810', '2595056', '', '', ''],
#  ['Algeria', 'DZA', '1811', '2604775', '', '', ''],
#  ['Algeria', 'DZA', '1812', '2614945', '', '', ''],
#  ['Algeria', 'DZA', '1813', '2625571', '', '', ''],
#  ['Algeria', 'DZA', '1814', '2636656', '', '', ''],
#  ['Algeria', 'DZA', '1815', '2648205', '', '', ''],
#  ['Algeria', 'DZA', '1816', '2660224', '', '', ''],
#  ['Algeria', 'DZA', '1817', '2672716', '', '', ''],
#  ['Algeria', 'DZA', '1818', '2685686', '', '', ''],
#  ['Algeria', 'DZA', '1819', '2699138', '', '', ''],
#  ['Algeria', 'DZA', '1820', '2713079', '', '', ''],
#  ['Algeria', 'DZA', '1821', '2727511', '', '', ''],
#  ['Algeria', 'DZA', '1822', '2742441', '', '', ''],
#  ['Algeria', 'DZA', '1823', '2757872', '', '', ''],
#  ['Algeria', 'DZA', '1824', '2773810', '', '', ''],
#  ['Algeria', 'DZA', '1825', '2790260', '', '', ''],
#  ['Algeria', 'DZA', '1826', '2807226', '', '', ''],
#  ['Algeria', 'DZA', '1827', '2824713', '', '', ''],
#  ['Algeria', 'DZA', '1828', '2842727', '', '', ''],
#  ['Algeria', 'DZA', '1829', '2861273', '', '', ''],
#  ['Algeria', 'DZA', '1830', '2880355', '', '', ''],
#  ['Algeria', 'DZA', '1831', '2899979', '', '', ''],
#  ['Algeria', 'DZA', '1832', '2919737', '', '', ''],
#  ['Algeria', 'DZA', '1833', '2939629', '', '', ''],
#  ['Algeria', 'DZA', '1834', '2959657', '', '', ''],
#  ['Algeria', 'DZA', '1835', '2979821', '', '', ''],
#  ['Algeria', 'DZA', '1836', '3000123', '', '', ''],
#  ['Algeria', 'DZA', '1837', '3020562', '', '', ''],
#  ['Algeria', 'DZA', '1838', '3041142', '', '', ''],
#  ['Algeria', 'DZA', '1839', '3061861', '', '', ''],
#  ['Algeria', 'DZA', '1840', '3082721', '', '', ''],
#  ['Algeria', 'DZA', '1841', '3103724', '', '', ''],
#  ['Algeria', 'DZA', '1842', '3124870', '', '', ''],
#  ['Algeria', 'DZA', '1843', '3146160', '', '', ''],
#  ['Algeria', 'DZA', '1844', '3167595', '', '', ''],
#  ['Algeria', 'DZA', '1845', '3189175', '', '', ''],
#  ['Algeria', 'DZA', '1846', '3210903', '', '', ''],
#  ['Algeria', 'DZA', '1847', '3232779', '', '', ''],
#  ['Algeria', 'DZA', '1848', '3254804', '', '', ''],
#  ['Algeria', 'DZA', '1849', '3276979', '', '', ''],
#  ['Algeria', 'DZA', '1850', '3299305', '', '', ''],
#  ['Algeria', 'DZA', '1851', '3322288', '', '', ''],
#  ['Algeria', 'DZA', '1852', '3345431', '', '', ''],
#  ['Algeria', 'DZA', '1853', '3368734', '', '', ''],
#  ['Algeria', 'DZA', '1854', '3392201', '', '', ''],
#  ['Algeria', 'DZA', '1855', '3415830', '', '', ''],
#  ['Algeria', 'DZA', '1856', '3439624', '', '', ''],
#  ['Algeria', 'DZA', '1857', '3463583', '', '', ''],
#  ['Algeria', 'DZA', '1858', '3487710', '', '', ''],
#  ['Algeria', 'DZA', '1859', '3512004', '', '', ''],
#  ['Algeria', 'DZA', '1860', '3536468', '', '', ''],
#  ['Algeria', 'DZA', '1861', '3561454', '', '', ''],
#  ['Algeria', 'DZA', '1862', '3586971', '', '', ''],
#  ['Algeria', 'DZA', '1863', '3613024', '', '', ''],
#  ['Algeria', 'DZA', '1864', '3639622', '', '', ''],
#  ['Algeria', 'DZA', '1865', '3666770', '', '', ''],
#  ['Algeria', 'DZA', '1866', '3694476', '', '', ''],
#  ['Algeria', 'DZA', '1867', '3722748', '', '', ''],
#  ['Algeria', 'DZA', '1868', '3751592', '', '', ''],
#  ['Algeria', 'DZA', '1869', '3781016', '', '', ''],
#  ['Algeria', 'DZA', '1870', '3811028', '', '', ''],
#  ['Algeria', 'DZA', '1871', '3841635', '', '', ''],
#  ['Algeria', 'DZA', '1872', '3872845', '', '', ''],
#  ['Algeria', 'DZA', '1873', '3902099', '', '', ''],
#  ['Algeria', 'DZA', '1874', '3934634', '', '', ''],
#  ['Algeria', 'DZA', '1875', '3967833', '', '', ''],
#  ['Algeria', 'DZA', '1876', '4001706', '', '', ''],
#  ['Algeria', 'DZA', '1877', '4034621', '', '', ''],
#  ['Algeria', 'DZA', '1878', '4070192', '', '', ''],
#  ['Algeria', 'DZA', '1879', '4106516', '', '', ''],
#  ['Algeria', 'DZA', '1880', '4143163', '', '', ''],
#  ['Algeria', 'DZA', '1881', '4179287', '', '', ''],
#  ['Algeria', 'DZA', '1882', '4216584', '', '', ''],
#  ['Algeria', 'DZA', '1883', '4254213', '', '', ''],
#  ['Algeria', 'DZA', '1884', '4291414', '', '', ''],
#  ['Algeria', 'DZA', '1885', '4329711', '', '', ''],
#  ['Algeria', 'DZA', '1886', '4368350', '', '', ''],
#  ['Algeria', 'DZA', '1887', '4406661', '', '', ''],
#  ['Algeria', 'DZA', '1888', '4445986', '', '', ''],
#  ['Algeria', 'DZA', '1889', '4485662', '', '', ''],
#  ['Algeria', 'DZA', '1890', '4525691', '', '', ''],
#  ['Algeria', 'DZA', '1891', '4566078', '', '', ''],
#  ['Algeria', 'DZA', '1892', '4606825', '', '', ''],
#  ['Algeria', 'DZA', '1893', '4647936', '', '', ''],
#  ['Algeria', 'DZA', '1894', '4689414', '', '', ''],
#  ['Algeria', 'DZA', '1895', '4731261', '', '', ''],
#  ['Algeria', 'DZA', '1896', '4773482', '', '', ''],
#  ['Algeria', 'DZA', '1897', '4816080', '', '', ''],
#  ['Algeria', 'DZA', '1898', '4859057', '', '', ''],
#  ['Algeria', 'DZA', '1899', '4902418', '', '', ''],
#  ['Algeria', 'DZA', '1900', '4946166', '', '', ''],
#  ['Algeria', 'DZA', '1901', '4990304', '', '', ''],
#  ['Algeria', 'DZA', '1902', '5034196', '', '', ''],
#  ['Algeria', 'DZA', '1903', '5079119', '', '', ''],
#  ['Algeria', 'DZA', '1904', '5124443', '', '', ''],
#  ['Algeria', 'DZA', '1905', '5170172', '', '', ''],
#  ['Algeria', 'DZA', '1906', '5216308', '', '', ''],
#  ['Algeria', 'DZA', '1907', '5261920', '', '', ''],
#  ['Algeria', 'DZA', '1908', '5308875', '', '', ''],
#  ['Algeria', 'DZA', '1909', '5356248', '', '', ''],
#  ['Algeria', 'DZA', '1910', '5404045', '', '', ''],
#  ['Algeria', 'DZA', '1911', '5451990', '', '', ''],
#  ['Algeria', 'DZA', '1912', '5500641', '', '', ''],
#  ['Algeria', 'DZA', '1913', '5556904', '', '', ''],
#  ['Algeria', 'DZA', '1914', '5620940', '', '', ''],
#  ['Algeria', 'DZA', '1915', '5692913', '', '', ''],
#  ['Algeria', 'DZA', '1916', '5765808', '', '', ''],
#  ['Algeria', 'DZA', '1917', '5839635', '', '', ''],
#  ['Algeria', 'DZA', '1918', '5913223', '', '', ''],
#  ['Algeria', 'DZA', '1919', '5988038', '', '', ''],
#  ['Algeria', 'DZA', '1920', '6063800', '', '', ''],
#  ['Algeria', 'DZA', '1921', '6140520', '', '', ''],
#  ['Algeria', 'DZA', '1922', '6218211', '', '', ''],
#  ['Algeria', 'DZA', '1923', '6296885', '', '28.822399', ''],
#  ['Algeria', 'DZA', '1924', '6376554', '', '', ''],
#  ['Algeria', 'DZA', '1925', '6457232', '', '', ''],
#  ['Algeria', 'DZA', '1926', '6538930', '', '', ''],
#  ['Algeria', 'DZA', '1927', '6621661', '', '', ''],
#  ['Algeria', 'DZA', '1928', '6705440', '', '', ''],
#  ['Algeria', 'DZA', '1929', '6790278', '', '', ''],
#  ['Algeria', 'DZA', '1930', '6876190', '', '', ''],
#  ['Algeria', 'DZA', '1931', '6963188', '', '', ''],
#  ['Algeria', 'DZA', '1932', '7051288', '', '', ''],
#  ['Algeria', 'DZA', '1933', '7140502', '', '31.219999', ''],
#  ['Algeria', 'DZA', '1934', '7230845', '', '', ''],
#  ['Algeria', 'DZA', '1935', '7322331', '', '', ''],
#  ['Algeria', 'DZA', '1936', '7414974', '', '', ''],
#  ['Algeria', 'DZA', '1937', '7508790', '', '', ''],
#  ['Algeria', 'DZA', '1938', '7603792', '', '', ''],
#  ['Algeria', 'DZA', '1939', '7699997', '', '', ''],
#  ['Algeria', 'DZA', '1940', '7797418', '', '', ''],
#  ['Algeria', 'DZA', '1941', '7896073', '', '', ''],
#  ['Algeria', 'DZA', '1942', '7995975', '', '', ''],
#  ['Algeria', 'DZA', '1943', '8097142', '', '33.720001', ''],
#  ['Algeria', 'DZA', '1944', '8199588', '', '', ''],
#  ['Algeria', 'DZA', '1945', '8303331', '', '', ''],
#  ['Algeria', 'DZA', '1946', '8408386', '', '', ''],
#  ['Algeria', 'DZA', '1947', '8514770', '', '', ''],
#  ['Algeria', 'DZA', '1948', '8622500', '', '', ''],
#  ['Algeria', 'DZA', '1949', '8731594', '', '', ''],
#  ['Algeria', 'DZA', '1950', '8872000', '', '42.087', ''],
#  ['Algeria', 'DZA', '1951', '9023000', '', '42.282', ''],
#  ['Algeria', 'DZA', '1952', '9186000', '', '42.677', ''],
#  ['Algeria', 'DZA', '1953', '9364000', '', '43.081', ''],
#  ['Algeria', 'DZA', '1954', '9560000', '', '43.494', ''],
#  ['Algeria', 'DZA', '1955', '9774000', '', '43.916', ''],
#  ['Algeria', 'DZA', '1956', '10006000', '', '44.347', ''],
#  ['Algeria', 'DZA', '1957', '10254000', '', '44.786', ''],
#  ['Algeria', 'DZA', '1958', '10514000', '', '45.232', ''],
#  ['Algeria', 'DZA', '1959', '10783000', '', '45.684', ''],
#  ['Algeria', 'DZA', '1960', '11058000', '', '46.141', ''],
#  ['Algeria', 'DZA', '1961', '11336000', '', '46.599', ''],
#  ['Algeria', 'DZA', '1962', '11620000', '', '47.056', ''],
#  ['Algeria', 'DZA', '1963', '11913000', '', '47.509', ''],
#  ['Algeria', 'DZA', '1964', '12222000', '', '47.958', ''],
#  ['Algeria', 'DZA', '1965', '12551000', '', '48.394', ''],
#  ['Algeria', 'DZA', '1966', '12903000', '', '48.811', ''],
#  ['Algeria', 'DZA', '1967', '13275000', '', '49.21', ''],
#  ['Algeria', 'DZA', '1968', '13664000', '', '49.597', ''],
#  ['Algeria', 'DZA', '1969', '14062000', '', '49.982', ''],
#  ['Algeria', 'DZA', '1970', '14465000', '', '50.372', '6334'],
#  ['Algeria', 'DZA', '1971', '14872000', '', '50.773', '5984'],
#  ['Algeria', 'DZA', '1972', '15286000', '', '51.201', '6615'],
#  ['Algeria', 'DZA', '1973', '15710000', '', '51.676', '6993'],
#  ['Algeria', 'DZA', '1974', '16149000', '', '52.218', '8977'],
#  ['Algeria', 'DZA', '1975', '16608000', '', '52.866', '9525'],
#  ['Algeria', 'DZA', '1976', '17086000', '', '53.661', '9227'],
#  ['Algeria', 'DZA', '1977', '17583000', '', '54.609', '9969'],
#  ['Algeria', 'DZA', '1978', '18102000', '', '55.7', '10922'],
#  ['Algeria', 'DZA', '1979', '18648000', '', '56.909', '11511'],
#  ['Algeria', 'DZA', '1980', '19222000', '', '58.198', '11630'],
#  ['Algeria', 'DZA', '1981', '19824000', '', '59.519', '12258'],
#  ['Algeria', 'DZA', '1982', '20453000', '', '60.813', '12243'],
#  ['Algeria', 'DZA', '1983', '21102000', '', '62.029', '12299'],
#  ['Algeria', 'DZA', '1984', '21764000', '', '63.13', '12283'],
#  ['Algeria', 'DZA', '1985', '22432000', '', '64.087', '12809'],
#  ['Algeria', 'DZA', '1986', '23102000', '', '64.884', '10761'],
#  ['Algeria', 'DZA', '1987', '23774000', '', '65.545', '9717'],
#  ['Algeria', 'DZA', '1988', '24443000', '', '66.097', '8437'],
#  ['Algeria', 'DZA', '1989', '25106000', '', '66.554', '8381'],
#  ['Algeria', 'DZA', '1990', '25759000', '', '66.938', '8312'],
#  ['Algeria', 'DZA', '1991', '26400000', '', '67.27', '7692'],
#  ['Algeria', 'DZA', '1992', '27028000', '', '67.575', '7893'],
#  ['Algeria', 'DZA', '1993', '27636000', '', '67.877', '7171'],
#  ['Algeria', 'DZA', '1994', '28214000', '', '68.194', '6966'],
#  ['Algeria', 'DZA', '1995', '28758000', '', '68.54', '7079'],
#  ['Algeria', 'DZA', '1996', '29266000', '', '68.919', '7215'],
#  ['Algeria', 'DZA', '1997', '29743000', '', '69.323', '6897'],
#  ['Algeria', 'DZA', '1998', '30193000', '', '69.745', '7114'],
#  ['Algeria', 'DZA', '1999', '30623000', '', '70.183', '7359'],
#  ['Algeria', 'DZA', '2000', '31042000', '', '70.64', '8255'],
#  ['Algeria', 'DZA', '2001', '31452000', '', '71.116', '8153'],
#  ['Algeria', 'DZA', '2002', '31855000', '', '71.605', '8462'],
#  ['Algeria', 'DZA', '2003', '32264000', '', '72.101', '9071'],
#  ['Algeria', 'DZA', '2004', '32692000', '', '72.594', '9516'],
#  ['Algeria', 'DZA', '2005', '33150000', '', '73.072', '10795'],
#  ['Algeria', 'DZA', '2006', '33641000', '', '73.521', '11585'],
#  ['Algeria', 'DZA', '2007', '34167000', '', '73.936', '11751'],
#  ['Algeria', 'DZA', '2008', '34731000', '', '74.311', '12270'],
#  ['Algeria', 'DZA', '2009', '35334000', '', '74.644', '11172'],
#  ['Algeria', 'DZA', '2010', '35977000', '', '74.938', '12510'],
#  ['Algeria', 'DZA', '2011', '36661000', '', '75.199', '13204'],
#  ['Algeria', 'DZA', '2012', '37384000', '', '75.436', '13242'],
#  ['Algeria', 'DZA', '2013', '38140000', '', '75.661', '12998'],
#  ['Algeria', 'DZA', '2014', '38924000', '', '75.878', '12782'],
#  ['Algeria', 'DZA', '2015', '39728000', 'Africa', '76.09', '13024'],
#  ['Algeria', 'DZA', '2016', '40551000', '', '76.298', '13328'],
#  ['Algeria', 'DZA', '2017', '41389000', '', '76.499', ''],
#  ['Algeria', 'DZA', '2018', '42228000', '', '76.693', ''],
#  ['Algeria', 'DZA', '2019', '43053000', '', '76.88', ''],
#  ['American Samoa', 'ASM', '1950', '19000', '', '63.775', ''],
#  ['American Samoa', 'ASM', '1951', '19000', '', '63.901', ''],
#  ['American Samoa', 'ASM', '1952', '20000', '', '64.159', ''],
#  ['American Samoa', 'ASM', '1953', '20000', '', '64.425', ''],
#  ['American Samoa', 'ASM', '1954', '20000', '', '64.701', ''],
#  ['American Samoa', 'ASM', '1955', '20000', '', '64.985', ''],
#  ['American Samoa', 'ASM', '1956', '20000', '', '65.27', ''],
#  ['American Samoa', 'ASM', '1957', '20000', '', '65.55', ''],
#  ['American Samoa', 'ASM', '1958', '20000', '', '65.813', ''],
#  ['American Samoa', 'ASM', '1959', '20000', '', '66.033', ''],
#  ['American Samoa', 'ASM', '1960', '20000', '', '66.187', ''],
#  ['American Samoa', 'ASM', '1961', '21000', '', '66.251', ''],
#  ['American Samoa', 'ASM', '1962', '21000', '', '66.213', ''],
#  ['American Samoa', 'ASM', '1963', '22000', '', '66.079', ''],
#  ['American Samoa', 'ASM', '1964', '23000', '', '65.876', ''],
#  ['American Samoa', 'ASM', '1965', '24000', '', '65.671', ''],
#  ['American Samoa', 'ASM', '1966', '24000', '', '65.544', ''],
#  ['American Samoa', 'ASM', '1967', '25000', '', '65.557', ''],
#  ['American Samoa', 'ASM', '1968', '26000', '', '65.742', ''],
#  ['American Samoa', 'ASM', '1969', '27000', '', '66.1', ''],
#  ['American Samoa', 'ASM', '1970', '27000', '', '66.601', ''],
#  ['American Samoa', 'ASM', '1971', '28000', '', '67.185', ''],
#  ['American Samoa', 'ASM', '1972', '29000', '', '67.772', ''],
#  ['American Samoa', 'ASM', '1973', '29000', '', '68.299', ''],
#  ['American Samoa', 'ASM', '1974', '30000', '', '68.735', ''],
#  ['American Samoa', 'ASM', '1975', '30000', '', '69.071', ''],
#  ['American Samoa', 'ASM', '1976', '30000', '', '69.319', ''],
#  ['American Samoa', 'ASM', '1977', '31000', '', '69.517', ''],
#  ['American Samoa', 'ASM', '1978', '31000', '', '69.697', ''],
#  ['American Samoa', 'ASM', '1979', '32000', '', '69.867', ''],
#  ['American Samoa', 'ASM', '1980', '33000', '', '70.033', ''],
#  ['American Samoa', 'ASM', '1981', '34000', '', '70.194', ''],
#  ['American Samoa', 'ASM', '1982', '35000', '', '70.344', ''],
#  ['American Samoa', 'ASM', '1983', '36000', '', '70.479', ''],
#  ['American Samoa', 'ASM', '1984', '38000', '', '70.597', ''],
#  ['American Samoa', 'ASM', '1985', '40000', '', '70.7', ''],
#  ['American Samoa', 'ASM', '1986', '41000', '', '70.786', ''],
#  ['American Samoa', 'ASM', '1987', '43000', '', '70.856', ''],
#  ['American Samoa', 'ASM', '1988', '44000', '', '70.912', ''],
#  ['American Samoa', 'ASM', '1989', '46000', '', '70.958', ''],
#  ['American Samoa', 'ASM', '1990', '47000', '', '70.996', ''],
#  ['American Samoa', 'ASM', '1991', '49000', '', '71.03', ''],
#  ['American Samoa', 'ASM', '1992', '50000', '', '71.063', ''],
#  ['American Samoa', 'ASM', '1993', '51000', '', '71.097', ''],
#  ['American Samoa', 'ASM', '1994', '52000', '', '71.132', ''],
#  ['American Samoa', 'ASM', '1995', '53000', '', '71.163', ''],
#  ['American Samoa', 'ASM', '1996', '54000', '', '71.183', ''],
#  ['American Samoa', 'ASM', '1997', '55000', '', '71.19', ''],
#  ['American Samoa', 'ASM', '1998', '56000', '', '71.186', ''],
#  ['American Samoa', 'ASM', '1999', '57000', '', '71.179', ''],
#  ['American Samoa', 'ASM', '2000', '58000', '', '71.184', ''],
#  ['American Samoa', 'ASM', '2001', '58000', '', '71.222', ''],
#  ['American Samoa', 'ASM', '2002', '59000', '', '71.305', ''],
#  ['American Samoa', 'ASM', '2003', '59000', '', '71.439', ''],
#  ['American Samoa', 'ASM', '2004', '60000', '', '71.624', ''],
#  ['American Samoa', 'ASM', '2005', '60000', '', '71.853', ''],
#  ['American Samoa', 'ASM', '2006', '59000', '', '72.116', ''],
#  ['American Samoa', 'ASM', '2007', '58000', '', '72.392', ''],
#  ['American Samoa', 'ASM', '2008', '57000', '', '72.661', ''],
#  ['American Samoa', 'ASM', '2009', '57000', '', '72.911', ''],
#  ['American Samoa', 'ASM', '2010', '56000', '', '73.126', ''],
#  ['American Samoa', 'ASM', '2011', '56000', '', '73.295', ''],
#  ['American Samoa', 'ASM', '2012', '56000', '', '73.419', ''],
#  ['American Samoa', 'ASM', '2013', '56000', '', '73.506', ''],
#  ['American Samoa', 'ASM', '2014', '56000', '', '73.559', ''],
#  ['American Samoa', 'ASM', '2015', '56000', 'Oceania', '73.588', ''],
#  ['American Samoa', 'ASM', '2016', '56000', '', '73.609', ''],
#  ['American Samoa', 'ASM', '2017', '56000', '', '73.636', ''],
#  ['American Samoa', 'ASM', '2018', '55000', '', '73.679', ''],
#  ['American Samoa', 'ASM', '2019', '55000', '', '73.745', ''],
#  ['Americas', '', '1770', '', '', '34.8', ''],
#  ['Americas', '', '1830', '', '', '34.8', ''],
#  ['Americas', '', '1850', '', '', '35.1', ''],
#  ['Americas', '', '1870', '', '', '35.1', ''],
#  ['Americas', '', '1900', '', '', '41', ''],
#  ['Americas', '', '1913', '', '', '45.1', ''],
#  ['Americas', '', '1950', '', '', '59.30469677', ''],
#  ['Americas', '', '1951', '', '', '59.46994456', ''],
#  ['Americas', '', '1952', '', '', '59.85612063', ''],
#  ['Americas', '', '1953', '', '', '60.23429871', ''],
#  ['Americas', '', '1954', '', '', '60.60279722', ''],
#  ['Americas', '', '1955', '', '', '60.95963613', ''],
#  ['Americas', '', '1956', '', '', '61.30299762', ''],
#  ['Americas', '', '1957', '', '', '61.63176706', ''],
#  ['Americas', '', '1958', '', '', '61.94457224', ''],
#  ['Americas', '', '1959', '', '', '62.23971836', ''],
#  ['Americas', '', '1960', '', '', '62.51586761', ''],
#  ['Americas', '', '1961', '', '', '62.77254009', ''],
#  ['Americas', '', '1962', '', '', '63.01148094', ''],
#  ['Americas', '', '1963', '', '', '63.23578485', ''],
#  ['Americas', '', '1964', '', '', '63.45157331', ''],
#  ['Americas', '', '1965', '', '', '63.66625528', ''],
#  ['Americas', '', '1966', '', '', '63.88622618', ''],
#  ['Americas', '', '1967', '', '', '64.11691127', ''],
#  ['Americas', '', '1968', '', '', '64.36515254', ''],
#  ['Americas', '', '1969', '', '', '64.63369933', ''],
#  ['Americas', '', '1970', '', '', '64.92574088', ''],
#  ['Americas', '', '1971', '', '', '65.24267958', ''],
#  ['Americas', '', '1972', '', '', '65.58026746', ''],
#  ['Americas', '', '1973', '', '', '65.93072577', ''],
#  ['Americas', '', '1974', '', '', '66.28955265', ''],
#  ['Americas', '', '1975', '', '', '66.65087235', ''],
#  ['Americas', '', '1976', '', '', '67.00899463', ''],
#  ['Americas', '', '1977', '', '', '67.35940074', ''],
#  ['Americas', '', '1978', '', '', '67.69830141', ''],
#  ['Americas', '', '1979', '', '', '68.02206614', ''],
#  ['Americas', '', '1980', '', '', '68.32929356', ''],
#  ['Americas', '', '1981', '', '', '68.61703445', ''],
#  ['Americas', '', '1982', '', '', '68.89015226', ''],
#  ['Americas', '', '1983', '', '', '69.1519207', ''],
#  ['Americas', '', '1984', '', '', '69.40474575', ''],
#  ['Americas', '', '1985', '', '', '69.65325858', ''],
#  ['Americas', '', '1986', '', '', '69.90010634', ''],
#  ['Americas', '', '1987', '', '', '70.14853528', ''],
#  ['Americas', '', '1988', '', '', '70.40128342', ''],
#  ['Americas', '', '1989', '', '', '70.65779572', ''],
#  ['Americas', '', '1990', '', '', '70.92044409', ''],
#  ['Americas', '', '1991', '', '', '71.18773869', ''],
#  ['Americas', '', '1992', '', '', '71.45792226', ''],
#  ['Americas', '', '1993', '', '', '71.72880883', ''],
#  ['Americas', '', '1994', '', '', '71.99914275', ''],
#  ['Americas', '', '1995', '', '', '72.26824757', ''],
#  ['Americas', '', '1996', '', '', '72.53597252', ''],
#  ['Americas', '', '1997', '', '', '72.8009705', ''],
#  ['Americas', '', '1998', '', '', '73.06324586', ''],
#  ['Americas', '', '1999', '', '', '73.32034347', ''],
#  ['Americas', '', '2000', '', '', '73.57207701', ''],
#  ['Americas', '', '2001', '', '', '73.81901117', ''],
#  ['Americas', '', '2002', '', '', '74.06140216', ''],
#  ['Americas', '', '2003', '', '', '74.29901207', ''],
#  ['Americas', '', '2004', '', '', '74.53184348', ''],
#  ['Americas', '', '2005', '', '', '74.75972955', ''],
#  ['Americas', '', '2006', '', '', '74.98255907', ''],
#  ['Americas', '', '2007', '', '', '75.19889267', ''],
#  ['Americas', '', '2008', '', '', '75.40791766', ''],
#  ['Americas', '', '2009', '', '', '75.6064355', ''],
#  ['Americas', '', '2010', '', '', '75.79106424', ''],
#  ['Americas', '', '2011', '', '', '75.95720977', ''],
#  ['Americas', '', '2012', '', '', '76.10318017', ''],
#  ['Americas', '', '2013', '', '', '76.23112521', ''],
#  ['Americas', '', '2014', '', '', '76.34333386', ''],
#  ['Americas', '', '2015', '', '', '76.44286453', ''],
#  ['Americas', '', '2016', '', '', '76.53703933', ''],
#  ['Americas', '', '2017', '', '', '76.62993096', ''],
#  ['Americas', '', '2018', '', '', '76.72842701', ''],
#  ['Americas', '', '2019', '', '', '76.83538896', ''],
#  ['Andorra', 'AND', '1800', '2654', '', '', ''],
#  ['Andorra', 'AND', '1801', '2654', '', '', ''],
#  ['Andorra', 'AND', '1802', '2654', '', '', ''],
#  ['Andorra', 'AND', '1803', '2654', '', '', ''],
#  ['Andorra', 'AND', '1804', '2654', '', '', ''],
#  ['Andorra', 'AND', '1805', '2654', '', '', ''],
#  ['Andorra', 'AND', '1806', '2654', '', '', ''],
#  ['Andorra', 'AND', '1807', '2654', '', '', ''],
#  ['Andorra', 'AND', '1808', '2654', '', '', ''],
#  ['Andorra', 'AND', '1809', '2654', '', '', ''],
#  ['Andorra', 'AND', '1810', '2654', '', '', ''],
#  ['Andorra', 'AND', '1811', '2655', '', '', ''],
#  ['Andorra', 'AND', '1812', '2656', '', '', ''],
#  ['Andorra', 'AND', '1813', '2659', '', '', ''],
#  ['Andorra', 'AND', '1814', '2662', '', '', ''],
#  ['Andorra', 'AND', '1815', '2667', '', '', ''],
#  ['Andorra', 'AND', '1816', '2672', '', '', ''],
#  ['Andorra', 'AND', '1817', '2677', '', '', ''],
#  ['Andorra', 'AND', '1818', '2684', '', '', ''],
#  ['Andorra', 'AND', '1819', '2692', '', '', ''],
#  ['Andorra', 'AND', '1820', '2700', '', '', ''],
#  ['Andorra', 'AND', '1821', '2710', '', '', ''],
#  ['Andorra', 'AND', '1822', '2720', '', '', ''],
#  ['Andorra', 'AND', '1823', '2731', '', '', ''],
#  ['Andorra', 'AND', '1824', '2743', '', '', ''],
#  ['Andorra', 'AND', '1825', '2756', '', '', ''],
#  ['Andorra', 'AND', '1826', '2770', '', '', ''],
#  ['Andorra', 'AND', '1827', '2785', '', '', ''],
#  ['Andorra', 'AND', '1828', '2801', '', '', ''],
#  ['Andorra', 'AND', '1829', '2817', '', '', ''],
#  ['Andorra', 'AND', '1830', '2835', '', '', ''],
#  ['Andorra', 'AND', '1831', '2854', '', '', ''],
#  ['Andorra', 'AND', '1832', '2872', '', '', ''],
#  ['Andorra', 'AND', '1833', '2891', '', '', ''],
#  ['Andorra', 'AND', '1834', '2910', '', '', ''],
#  ['Andorra', 'AND', '1835', '2929', '', '', ''],
#  ['Andorra', 'AND', '1836', '2948', '', '', ''],
#  ['Andorra', 'AND', '1837', '2968', '', '', ''],
#  ['Andorra', 'AND', '1838', '2987', '', '', ''],
#  ['Andorra', 'AND', '1839', '3007', '', '', ''],
#  ['Andorra', 'AND', '1840', '3026', '', '', ''],
#  ['Andorra', 'AND', '1841', '3046', '', '', ''],
#  ['Andorra', 'AND', '1842', '3066', '', '', ''],
#  ['Andorra', 'AND', '1843', '3086', '', '', ''],
#  ['Andorra', 'AND', '1844', '3106', '', '', ''],
#  ['Andorra', 'AND', '1845', '3127', '', '', ''],
#  ['Andorra', 'AND', '1846', '3147', '', '', ''],
#  ['Andorra', 'AND', '1847', '3168', '', '', ''],
#  ['Andorra', 'AND', '1848', '3188', '', '', ''],
#  ['Andorra', 'AND', '1849', '3209', '', '', ''],
#  ['Andorra', 'AND', '1850', '3230', '', '', ''],
#  ['Andorra', 'AND', '1851', '3250', '', '', ''],
#  ['Andorra', 'AND', '1852', '3270', '', '', ''],
#  ['Andorra', 'AND', '1853', '3290', '', '', ''],
#  ['Andorra', 'AND', '1854', '3311', '', '', ''],
#  ['Andorra', 'AND', '1855', '3331', '', '', ''],
#  ['Andorra', 'AND', '1856', '3352', '', '', ''],
#  ['Andorra', 'AND', '1857', '3373', '', '', ''],
#  ['Andorra', 'AND', '1858', '3393', '', '', ''],
#  ['Andorra', 'AND', '1859', '3414', '', '', ''],
#  ['Andorra', 'AND', '1860', '3435', '', '', ''],
#  ['Andorra', 'AND', '1861', '3457', '', '', ''],
#  ['Andorra', 'AND', '1862', '3478', '', '', ''],
#  ['Andorra', 'AND', '1863', '3500', '', '', ''],
#  ['Andorra', 'AND', '1864', '3521', '', '', ''],
#  ['Andorra', 'AND', '1865', '3543', '', '', ''],
#  ['Andorra', 'AND', '1866', '3565', '', '', ''],
#  ['Andorra', 'AND', '1867', '3587', '', '', ''],
#  ...]

# %%
del tableau[1]

# %%
for i in reversed(range(1,len(tableau))):
    k=tableau[i][2]
    k=int(k)
    if(k!=2015):
        del tableau[i]
tableau
# Out:
# [['Entity',
#   'Code',
#   'Year',
#   'Total population (Gapminder, HYDE & UN)',
#   'Continent',
#   'Life expectancy',
#   'Real GDP per capita in 2011US$, multiple benchmarks (Maddison Project Database (2018))'],
#  ['Afghanistan', 'AFG', '2015', '34414000', 'Asia', '63.377', '1928'],
#  ['Africa', '', '2015', '1182439040', '', '61.607', '4684'],
#  ['Akrotiri and Dhekelia', 'OWID_AKD', '2015', '', 'Asia', '', ''],
#  ['Albania', 'ALB', '2015', '2891000', 'Europe', '78.025', '10947'],
#  ['Algeria', 'DZA', '2015', '39728000', 'Africa', '76.09', '13024'],
#  ['American Samoa', 'ASM', '2015', '56000', 'Oceania', '73.588', ''],
#  ['Americas', '', '2015', '', '', '76.44286453', ''],
#  ['Andorra', 'AND', '2015', '78000', 'Europe', '83.073', ''],
#  ['Angola', 'AGO', '2015', '27884000', 'Africa', '59.398', '8631'],
#  ['Anguilla', 'AIA', '2015', '14000', 'North America', '81.332', ''],
#  ['Antarctica', 'ATA', '2015', '', 'Antarctica', '', ''],
#  ['Antigua and Barbuda',
#   'ATG',
#   '2015',
#   '94000',
#   'North America',
#   '76.483',
#   ''],
#  ['Argentina', 'ARG', '2015', '43075000', 'South America', '76.068', '19316'],
#  ['Armenia', 'ARM', '2015', '2926000', 'Asia', '74.467', '9552'],
#  ['Aruba', 'ABW', '2015', '104000', 'North America', '75.725', ''],
#  ['Asia', '', '2015', '4433475072', '', '72.62', ''],
#  ['Australia', 'AUS', '2015', '23932000', 'Oceania', '82.794', '44336'],
#  ['Austria', 'AUT', '2015', '8679000', 'Europe', '81.182', '44845'],
#  ['Austria-Hungary', 'OWID_AUH', '2015', '', 'Europe', '', ''],
#  ['Azerbaijan', 'AZE', '2015', '9623000', 'Asia', '72.266', '16045'],
#  ['Baden', 'OWID_BAD', '2015', '', 'Europe', '', ''],
#  ['Bahamas', 'BHS', '2015', '374000', 'North America', '73.088', ''],
#  ['Bahrain', 'BHR', '2015', '1372000', 'Asia', '76.762', '39197'],
#  ['Bangladesh', 'BGD', '2015', '156256000', 'Asia', '71.514', '3068'],
#  ['Barbados', 'BRB', '2015', '285000', 'North America', '78.801', '10030'],
#  ['Bavaria', 'OWID_BAV', '2015', '', 'Europe', '', ''],
#  ['Belarus', 'BLR', '2015', '9439000', 'Europe', '73.652', '19306'],
#  ['Belgium', 'BEL', '2015', '11288000', 'Europe', '80.969', '39531'],
#  ['Belize', 'BLZ', '2015', '361000', 'North America', '74.034', ''],
#  ['Benin', 'BEN', '2015', '10576000', 'Africa', '60.608', '2141'],
#  ['Bermuda', 'BMU', '2015', '64000', 'North America', '81.999', ''],
#  ['Bhutan', 'BTN', '2015', '728000', 'Asia', '70.419', ''],
#  ['Bolivia', 'BOL', '2015', '10870000', 'South America', '70.277', '5969'],
#  ['Bonaire Sint Eustatius and Saba',
#   'BES',
#   '2015',
#   '25000',
#   'North America',
#   '77.033',
#   ''],
#  ['Bosnia and Herzegovina',
#   'BIH',
#   '2015',
#   '3429000',
#   'Europe',
#   '76.865',
#   '10305'],
#  ['Botswana', 'BWA', '2015', '2121000', 'Africa', '67.338', '14626'],
#  ['Bouvet Island', 'BVT', '2015', '', 'Antarctica', '', ''],
#  ['Brazil', 'BRA', '2015', '204472000', 'South America', '74.994', '15377'],
#  ['British Indian Ocean Territory', 'IOT', '2015', '', 'Asia', '', ''],
#  ['British Virgin Islands',
#   'VGB',
#   '2015',
#   '29000',
#   'North America',
#   '78.411',
#   ''],
#  ['Brunei', 'BRN', '2015', '415000', 'Asia', '75.318', ''],
#  ['Bulgaria', 'BGR', '2015', '7200000', 'Europe', '74.584', '17254'],
#  ['Burkina Faso', 'BFA', '2015', '18111000', 'Africa', '59.919', '1527'],
#  ['Burundi', 'BDI', '2015', '10160000', 'Africa', '60.123', '723'],
#  ['Cambodia', 'KHM', '2015', '15521000', 'Asia', '68.637', '3139'],
#  ['Cameroon', 'CMR', '2015', '23298000', 'Africa', '57.583', '2754'],
#  ['Canada', 'CAN', '2015', '36027000', 'North America', '82.026', '42844'],
#  ['Cape Verde', 'CPV', '2015', '525000', 'Africa', '72.117', '6358'],
#  ['Cayman Islands', 'CYM', '2015', '62000', 'North America', '83.324', ''],
#  ['Central African Republic',
#   'CAF',
#   '2015',
#   '4493000',
#   'Africa',
#   '50.881',
#   '605'],
#  ['Chad', 'TCD', '2015', '14111000', 'Africa', '53.137', '2387'],
#  ['Channel Islands', 'OWID_CIS', '2015', '165000', 'Europe', '82.429', ''],
#  ['Chile', 'CHL', '2015', '17969000', 'South America', '79.646', '21340'],
#  ['China', 'CHN', '2015', '1406848000', 'Asia', '75.928', '12002'],
#  ['Christmas Island', 'CXR', '2015', '', 'Asia', '', ''],
#  ['Cocos Islands', 'CCK', '2015', '', 'Asia', '', ''],
#  ['Colombia', 'COL', '2015', '47521000', 'South America', '76.531', '12858'],
#  ['Comoros', 'COM', '2015', '777000', 'Africa', '63.471', '1706'],
#  ['Congo', 'COG', '2015', '4856000', 'Africa', '63.097', '4526'],
#  ['Cook Islands', 'COK', '2015', '18000', 'Oceania', '75.409', ''],
#  ['Costa Rica', 'CRI', '2015', '4848000', 'North America', '79.565', '13568'],
#  ["Cote d'Ivoire", 'CIV', '2015', '23226000', 'Africa', '56.065', '3473'],
#  ['Croatia', 'HRV', '2015', '4233000', 'Europe', '77.892', '20905'],
#  ['Cuba', 'CUB', '2015', '11325000', 'North America', '78.561', '7889'],
#  ['Curacao', 'CUW', '2015', '160000', 'North America', '78.268', ''],
#  ['Cyprus', 'CYP', '2015', '1161000', 'Europe', '80.35', '25903'],
#  ['Czech Republic', 'CZE', '2015', '10601000', 'Europe', '78.692', '30410'],
#  ['Czechoslovakia', 'OWID_CZS', '2015', '', 'Europe', '', '29361'],
#  ['Democratic Republic of Congo',
#   'COD',
#   '2015',
#   '76245000',
#   'Africa',
#   '59.254',
#   '836'],
#  ['Denmark', 'DNK', '2015', '5689000', 'Europe', '80.475', '44939'],
#  ['Djibouti', 'DJI', '2015', '914000', 'Africa', '64.136', '3258'],
#  ['Dominica', 'DMA', '2015', '71000', 'North America', '74.194', '9537'],
#  ['Dominican Republic',
#   'DOM',
#   '2015',
#   '10282000',
#   'North America',
#   '73.241',
#   '13382'],
#  ['East Asia', '', '2015', '', '', '', '9998'],
#  ['East Germany', 'OWID_GDR', '2015', '', 'Europe', '', ''],
#  ['Eastern Europe', '', '2015', '', '', '', '19187'],
#  ['Ecuador', 'ECU', '2015', '16212000', 'South America', '76.143', '10914'],
#  ['Egypt', 'EGY', '2015', '92443000', 'Africa', '71.302', '11236'],
#  ['El Salvador', 'SLV', '2015', '6325000', 'North America', '72.412', '8163'],
#  ['Equatorial Guinea', 'GNQ', '2015', '1169000', 'Africa', '57.359', '35743'],
#  ['Eritrea', 'ERI', '2015', '3343000', 'Africa', '64.664', ''],
#  ['Eritrea and Ethiopia', 'OWID_ERE', '2015', '', 'Africa', '', ''],
#  ['Estonia', 'EST', '2015', '1315000', 'Europe', '77.783', '25790'],
#  ['Ethiopia', 'ETH', '2015', '100835000', 'Africa', '65.048', '1576'],
#  ['Europe', '', '2015', '743059008', '', '77.839', ''],
#  ['Faeroe Islands', 'FRO', '2015', '48000', 'Europe', '80.13', ''],
#  ['Falkland Islands', 'FLK', '2015', '3000', 'South America', '80.876', ''],
#  ['Fiji', 'FJI', '2015', '869000', 'Oceania', '67.103', ''],
#  ['Finland', 'FIN', '2015', '5481000', 'Europe', '81.196', '37920'],
#  ['Former USSR', '', '2015', '', '', '', '17953'],
#  ['Former Yugoslavia', '', '2015', '', '', '', '15888'],
#  ['France', 'FRA', '2015', '64453000', 'Europe', '82.224', '38448'],
#  ['French Guiana', 'GUF', '2015', '261000', 'South America', '79.555', ''],
#  ['French Polynesia', 'PYF', '2015', '273000', 'Oceania', '76.787', ''],
#  ['French Southern Territories', 'ATF', '2015', '', 'Antarctica', '', ''],
#  ['Gabon', 'GAB', '2015', '1948000', 'Africa', '64.913', '14315'],
#  ['Gambia', 'GMB', '2015', '2086000', 'Africa', '60.91', '1948'],
#  ['Georgia', 'GEO', '2015', '4024000', 'Asia', '72.973', '10198'],
#  ['Germany', 'DEU', '2015', '81787000', 'Europe', '80.77', '46426'],
#  ['Ghana', 'GHA', '2015', '27849000', 'Africa', '62.772', '3687'],
#  ['Gibraltar', 'GIB', '2015', '34000', 'Europe', '79.351', ''],
#  ['Greece', 'GRC', '2015', '10660000', 'Europe', '81.548', '24545'],
#  ['Greenland', 'GRL', '2015', '56000', 'North America', '71.407', ''],
#  ['Grenada', 'GRD', '2015', '110000', 'North America', '72.445', ''],
#  ['Guadeloupe', 'GLP', '2015', '400000', 'North America', '81.22', ''],
#  ['Guam', 'GUM', '2015', '162000', 'Oceania', '79.144', ''],
#  ['Guatemala', 'GTM', '2015', '16252000', 'North America', '73.25', '7055'],
#  ['Guernsey', 'GGY', '2015', '', 'Europe', '', ''],
#  ['Guinea', 'GIN', '2015', '11432000', 'Africa', '59.598', '1606'],
#  ['Guinea-Bissau', 'GNB', '2015', '1737000', 'Africa', '56.959', '1313'],
#  ['Guyana', 'GUY', '2015', '767000', 'South America', '69.262', ''],
#  ['Haiti', 'HTI', '2015', '10696000', 'North America', '62.485', '1649'],
#  ['Hanover', 'OWID_HAN', '2015', '', 'Europe', '', ''],
#  ['Heard Island and McDonald Islands',
#   'HMD',
#   '2015',
#   '',
#   'Antarctica',
#   '',
#   ''],
#  ['Hesse Electoral', 'OWID_HSE', '2015', '', 'Europe', '', ''],
#  ['Hesse Grand Ducal', 'OWID_HSG', '2015', '', 'Europe', '', ''],
#  ['Honduras', 'HND', '2015', '9113000', 'North America', '74.495', '4352'],
#  ['Hong Kong', 'HKG', '2015', '7186000', 'Asia', '84.043', '46504'],
#  ['Hungary', 'HUN', '2015', '9778000', 'Europe', '76.006', '23539'],
#  ['Iceland', 'ISL', '2015', '330000', 'Europe', '82.481', '40572'],
#  ['India', 'IND', '2015', '1310151936', 'Asia', '68.607', '5639'],
#  ['Indonesia', 'IDN', '2015', '258383008', 'Asia', '70.768', '10099'],
#  ['Iran', 'IRN', '2015', '78492000', 'Asia', '75.796', '15039'],
#  ['Iraq', 'IRQ', '2015', '35572000', 'Asia', '69.929', '13087'],
#  ['Ireland', 'IRL', '2015', '4652000', 'Europe', '81.344', '53372'],
#  ['Isle of Man', 'IMN', '2015', '83000', 'Europe', '80.82', ''],
#  ['Israel', 'ISR', '2015', '7978000', 'Asia', '82.34', '31729'],
#  ['Italy', 'ITA', '2015', '60578000', 'Europe', '82.828', '34673'],
#  ['Jamaica', 'JAM', '2015', '2891000', 'North America', '74.098', '7115'],
#  ['Japan', 'JPN', '2015', '127985000', 'Asia', '83.879', '36030'],
#  ['Jersey', 'JEY', '2015', '', 'Europe', '', ''],
#  ['Jordan', 'JOR', '2015', '9267000', 'Asia', '74.078', '11738'],
#  ['Kazakhstan', 'KAZ', '2015', '17572000', 'Asia', '71.319', '23408'],
#  ['Kenya', 'KEN', '2015', '47878000', 'Africa', '64.798', '3090'],
#  ['Kiribati', 'KIR', '2015', '111000', 'Oceania', '67.291', ''],
#  ['Kosovo', 'OWID_KOS', '2015', '', 'Europe', '', ''],
#  ['Kuwait', 'KWT', '2015', '3836000', 'Asia', '75.13', '68127'],
#  ['Kyrgyzstan', 'KGZ', '2015', '5959000', 'Asia', '70.876', '5910'],
#  ['Laos', 'LAO', '2015', '6741000', 'Asia', '66.546', '6001'],
#  ['Latin America', '', '2015', '623934016', '', '', '14400'],
#  ['Latin America and the Caribbean', '', '2015', '', '', '74.852', ''],
#  ['Latvia', 'LVA', '2015', '1998000', 'Europe', '74.733', '22724'],
#  ['Lebanon', 'LBN', '2015', '6533000', 'Asia', '78.768', '12665'],
#  ['Lesotho', 'LSO', '2015', '2059000', 'Africa', '51.038', '2954'],
#  ['Liberia', 'LBR', '2015', '4472000', 'Africa', '62.269', '798'],
#  ['Libya', 'LBY', '2015', '6418000', 'Africa', '72.121', '8514'],
#  ['Liechtenstein', 'LIE', '2015', '37000', 'Europe', '82.039', ''],
#  ['Lithuania', 'LTU', '2015', '2932000', 'Europe', '74.923', '25279'],
#  ['Luxembourg', 'LUX', '2015', '567000', 'Europe', '81.636', '67804'],
#  ['Macao', 'MAC', '2015', '602000', 'Asia', '83.707', ''],
#  ['Macedonia', 'MKD', '2015', '2079000', 'Europe', '75.406', '13586'],
#  ['Madagascar', 'MDG', '2015', '24234000', 'Africa', '65.539', '1288'],
#  ['Malawi', 'MWI', '2015', '16745000', 'Africa', '61.953', '960'],
#  ['Malaysia', 'MYS', '2015', '30271000', 'Asia', '75.461', '22075'],
#  ['Maldives', 'MDV', '2015', '455000', 'Asia', '77.691', ''],
#  ['Mali', 'MLI', '2015', '17439000', 'Africa', '57.509', '1563'],
#  ['Malta', 'MLT', '2015', '434000', 'Europe', '81.896', '26577'],
#  ['Marshall Islands', 'MHL', '2015', '57000', 'Oceania', '72.789', ''],
#  ['Martinique', 'MTQ', '2015', '378000', 'North America', '81.753', ''],
#  ['Mauritania', 'MRT', '2015', '4046000', 'Africa', '63.936', '3323'],
#  ['Mauritius', 'MUS', '2015', '1259000', 'Africa', '74.5', '18259'],
#  ['Mayotte', 'MYT', '2015', '240000', 'Africa', '79.408', ''],
#  ['Mecklenburg Schwerin', 'OWID_MEC', '2015', '', 'Europe', '', ''],
#  ['Mexico', 'MEX', '2015', '121858000', 'North America', '74.904', '15766'],
#  ['Micronesia (country)', 'FSM', '2015', '109000', 'Oceania', '67.315', ''],
#  ['Modena', 'OWID_MOD', '2015', '', 'Europe', '', ''],
#  ['Moldova', 'MDA', '2015', '4071000', 'Europe', '71.478', '5569'],
#  ['Monaco', 'MCO', '2015', '38000', 'Europe', '85.739', ''],
#  ['Mongolia', 'MNG', '2015', '2998000', 'Asia', '69.111', '11139'],
#  ['Montenegro', 'MNE', '2015', '627000', 'Europe', '76.452', '17738'],
#  ['Montserrat', 'MSR', '2015', '5000', 'North America', '74.339', ''],
#  ['Morocco', 'MAR', '2015', '34664000', 'Africa', '75.726', '7577'],
#  ['Mozambique', 'MOZ', '2015', '27042000', 'Africa', '57.206', '1277'],
#  ['Myanmar', 'MMR', '2015', '52681000', 'Asia', '65.81', '5834'],
#  ['Nagorno-Karabakh', 'OWID_NAG', '2015', '', 'Asia', '', ''],
#  ['Namibia', 'NAM', '2015', '2315000', 'Africa', '62.119', '11850'],
#  ['Nauru', 'NRU', '2015', '10000', 'Oceania', '59.758', ''],
#  ['Nepal', 'NPL', '2015', '27015000', 'Asia', '69.515', '2607'],
#  ['Netherlands', 'NLD', '2015', '16938000', 'Europe', '81.715', '48463'],
#  ['Netherlands Antilles', 'ANT', '2015', '', 'North America', '', ''],
#  ['New Caledonia', 'NCL', '2015', '271000', 'Oceania', '76.827', ''],
#  ['New Zealand', 'NZL', '2015', '4615000', 'Oceania', '81.713', '33445'],
#  ['Nicaragua', 'NIC', '2015', '6223000', 'North America', '73.649', '4699'],
#  ['Niger', 'NER', '2015', '20002000', 'Africa', '60.631', '895'],
#  ['Nigeria', 'NGA', '2015', '181136992', 'Africa', '53.112', '5540'],
#  ['Niue', 'NIU', '2015', '2000', 'Oceania', '73.135', ''],
#  ['Norfolk Island', 'NFK', '2015', '', 'Oceania', '', ''],
#  ['North America', '', '2015', '357031008', '', '', ''],
#  ['North Korea', 'PRK', '2015', '25184000', 'Asia', '71.481', '1720'],
#  ['Northern America', '', '2015', '', '', '79.223', ''],
#  ['Northern Cyprus', 'OWID_CYN', '2015', '', 'Asia', '', ''],
#  ['Northern Mariana Islands', 'MNP', '2015', '56000', 'Oceania', '75.279', ''],
#  ['Norway', 'NOR', '2015', '5200000', 'Europe', '81.912', '76305'],
#  ['Oceania', '', '2015', '39859000', '', '77.92', ''],
#  ['Oman', 'OMN', '2015', '4267000', 'Asia', '76.887', '37096'],
#  ['Pakistan', 'PAK', '2015', '199427008', 'Asia', '66.577', '5056'],
#  ['Palau', 'PLW', '2015', '18000', 'Oceania', '72.834', ''],
#  ['Palestine', 'PSE', '2015', '4529000', 'Asia', '73.442', '4422'],
#  ['Panama', 'PAN', '2015', '3968000', 'North America', '77.776', '20809'],
#  ['Papua New Guinea', 'PNG', '2015', '8108000', 'Oceania', '63.466', ''],
#  ['Paraguay', 'PRY', '2015', '6689000', 'South America', '73.662', '8364'],
#  ['Parma', 'OWID_PMA', '2015', '', 'Europe', '', ''],
#  ['Peru', 'PER', '2015', '30471000', 'South America', '75.792', '11215'],
#  ['Philippines', 'PHL', '2015', '102113000', 'Asia', '70.644', '6870'],
#  ['Pitcairn', 'PCN', '2015', '', 'Oceania', '', ''],
#  ['Poland', 'POL', '2015', '38034000', 'Europe', '77.859', '25310'],
#  ['Portugal', 'PRT', '2015', '10368000', 'Europe', '81.224', '27255'],
#  ['Puerto Rico', 'PRI', '2015', '3382000', 'North America', '79.52', '35384'],
#  ['Qatar', 'QAT', '2015', '2566000', 'Asia', '79.758', '139542'],
#  ['Republic of Vietnam', 'OWID_RVN', '2015', '', 'Asia', '', ''],
#  ['Reunion', 'REU', '2015', '863000', 'Africa', '79.775', ''],
#  ['Romania', 'ROU', '2015', '19925000', 'Europe', '75.476', '20549'],
#  ['Russia', 'RUS', '2015', '144984992', 'Europe', '71.464', '23118'],
#  ['Rwanda', 'RWA', '2015', '11369000', 'Africa', '67.45', '1676'],
#  ['Saint Barthlemy', '', '2015', '10000', '', '81.114', ''],
#  ['Saint BarthÃ©lemy', 'BLM', '2015', '', 'North America', '', ''],
#  ['Saint Helena', 'SHN', '2015', '6000', 'Africa', '80.202', ''],
#  ['Saint Kitts and Nevis',
#   'KNA',
#   '2015',
#   '51000',
#   'North America',
#   '75.532',
#   ''],
#  ['Saint Lucia', 'LCA', '2015', '179000', 'North America', '75.596', '10687'],
#  ['Saint Martin (French part)',
#   'MAF',
#   '2015',
#   '36000',
#   'North America',
#   '81.092',
#   ''],
#  ['Saint Pierre and Miquelon',
#   'SPM',
#   '2015',
#   '6000',
#   'North America',
#   '80.533',
#   ''],
#  ['Saint Vincent and the Grenadines',
#   'VCT',
#   '2015',
#   '109000',
#   'North America',
#   '72.095',
#   ''],
#  ['Samoa', 'WSM', '2015', '194000', 'Oceania', '72.73', ''],
#  ['San Marino', 'SMR', '2015', '33000', 'Europe', '84.375', ''],
#  ['Sao Tome and Principe',
#   'STP',
#   '2015',
#   '199000',
#   'Africa',
#   '69.377',
#   '3560'],
#  ['Saudi Arabia', 'SAU', '2015', '31718000', 'Asia', '74.651', '47737'],
#  ['Saxony', 'OWID_SAX', '2015', '', 'Europe', '', ''],
#  ['Senegal', 'SEN', '2015', '14578000', 'Africa', '66.747', '2446'],
#  ['Serbia', 'SRB', '2015', '8877000', 'Europe', '75.309', '13556'],
#  ['Serbia and Montenegro', 'OWID_SRM', '2015', '', 'Europe', '', ''],
#  ['Serbia excluding Kosovo', 'OWID_SEK', '2015', '', 'Europe', '', ''],
#  ['Seychelles', 'SYC', '2015', '95000', 'Africa', '73.182', '23984'],
#  ['Sierra Leone', 'SLE', '2015', '7172000', 'Africa', '52.941', '1033'],
#  ['Singapore', 'SGP', '2015', '5592000', 'Asia', '82.877', '67110'],
#  ['Sint Maarten (Dutch part)',
#   'SXM',
#   '2015',
#   '40000',
#   'North America',
#   '78.36',
#   ''],
#  ['Slovakia', 'SVK', '2015', '5436000', 'Europe', '76.827', '25896'],
#  ['Slovenia', 'SVN', '2015', '2071000', 'Europe', '80.673', '28077'],
#  ['Solomon Islands', 'SLB', '2015', '603000', 'Oceania', '72.173', ''],
#  ['Somalia', 'SOM', '2015', '13797000', 'Africa', '55.92', ''],
#  ['Somaliland', 'OWID_SML', '2015', '', 'Africa', '', ''],
#  ['South Africa', 'ZAF', '2015', '55386000', 'Africa', '62.649', '12054'],
#  ['South Georgia and the South Sandwich Islands',
#   'SGS',
#   '2015',
#   '',
#   'South America',
#   '',
#   ''],
#  ['South Korea', 'KOR', '2015', '50823000', 'Asia', '82.1', '35316'],
#  ['South Ossetia', 'OWID_SOS', '2015', '', 'Asia', '', ''],
#  ['South Sudan', 'SSD', '2015', '10716000', 'Africa', '56.855', ''],
#  ['Spain', 'ESP', '2015', '46672000', 'Europe', '82.981', '33376'],
#  ['Sri Lanka', 'LKA', '2015', '20908000', 'Asia', '76.316', '10734'],
#  ['Sudan', 'SDN', '2015', '38903000', 'Africa', '64.429', '3723'],
#  ['Suriname', 'SUR', '2015', '559000', 'South America', '71.249', ''],
#  ['Svalbard and Jan Mayen', 'SJM', '2015', '', 'Europe', '', ''],
#  ['Swaziland', 'SWZ', '2015', '1104000', 'Africa', '55.359', '7726'],
#  ['Sweden', 'SWE', '2015', '9765000', 'Europe', '82.251', '43464'],
#  ['Switzerland', 'CHE', '2015', '8297000', 'Europe', '83.142', '61476'],
#  ['Syria', 'SYR', '2015', '17997000', 'Asia', '69.908', '3509'],
#  ['Taiwan', 'TWN', '2015', '23557000', 'Asia', '79.743', '41805'],
#  ['Tajikistan', 'TJK', '2015', '8454000', 'Asia', '70.137', '3365'],
#  ['Tanzania', 'TZA', '2015', '51483000', 'Africa', '63.111', '2429'],
#  ['Thailand', 'THA', '2015', '68715000', 'Asia', '76.091', '13938'],
#  ['Timor', 'TLS', '2015', '1196000', 'Asia', '68.459', ''],
#  ['Togo', 'TGO', '2015', '7323000', 'Africa', '59.927', '1482'],
#  ['Tokelau', 'TKL', '2015', '1000', 'Oceania', '81.065', ''],
#  ['Tonga', 'TON', '2015', '101000', 'Oceania', '70.517', ''],
#  ['Transnistria', 'OWID_TRS', '2015', '', 'Europe', '', ''],
#  ['Trinidad and Tobago',
#   'TTO',
#   '2015',
#   '1370000',
#   'North America',
#   '72.941',
#   '30892'],
#  ['Tunisia', 'TUN', '2015', '11180000', 'Africa', '75.922', '10608'],
#  ['Turkey', 'TUR', '2015', '78529000', 'Asia', '76.532', '20808'],
#  ['Turkmenistan', 'TKM', '2015', '5565000', 'Asia', '67.704', '21262'],
#  ['Turks and Caicos Islands',
#   'TCA',
#   '2015',
#   '36000',
#   'North America',
#   '79.594',
#   ''],
#  ['Tuscany', 'OWID_TUS', '2015', '', 'Europe', '', ''],
#  ['Tuvalu', 'TUV', '2015', '11000', 'Oceania', '66.457', ''],
#  ['Two Sicilies', 'OWID_SIC', '2015', '', 'Europe', '', ''],
#  ['USSR', 'OWID_USS', '2015', '', 'Europe', '', ''],
#  ['Uganda', 'UGA', '2015', '38225000', 'Africa', '61.373', '1883'],
#  ['Ukraine', 'UKR', '2015', '44922000', 'Europe', '71.535', '9429'],
#  ['United Arab Emirates', 'ARE', '2015', '9263000', 'Asia', '77.285', '69237'],
#  ['United Kingdom', 'GBR', '2015', '65860000', 'Europe', '81.052', '38749'],
#  ['United Korea', 'OWID_KRU', '2015', '', 'Asia', '', ''],
#  ['United States',
#   'USA',
#   '2015',
#   '320878016',
#   'North America',
#   '78.91',
#   '52591'],
#  ['United States Minor Outlying Islands',
#   'UMI',
#   '2015',
#   '',
#   'Oceania',
#   '',
#   ''],
#  ['United States Virgin Islands',
#   'VIR',
#   '2015',
#   '105000',
#   'North America',
#   '79.914',
#   ''],
#  ['Uruguay', 'URY', '2015', '3412000', 'South America', '77.369', '19668'],
#  ['Uzbekistan', 'UZB', '2015', '30930000', 'Asia', '70.928', '9107'],
#  ['Vanuatu', 'VUT', '2015', '271000', 'Oceania', '69.869', ''],
#  ['Vatican', 'VAT', '2015', '1000', 'Europe', '74.344', ''],
#  ['Venezuela', 'VEN', '2015', '30082000', 'South America', '72.584', '16257'],
#  ['Vietnam', 'VNM', '2015', '92677000', 'Asia', '75.11', '5733'],
#  ['Wallis and Futuna', 'WLF', '2015', '12000', 'Oceania', '79.3', ''],
#  ['West Germany', 'OWID_GFR', '2015', '', 'Europe', '', ''],
#  ['Western Asia', '', '2015', '', '', '', '21226'],
#  ['Western Europe', '', '2015', '', '', '', '40175'],
#  ['Western Offshoots', '', '2015', '', '', '', '50951'],
#  ['Western Sahara', 'ESH', '2015', '526000', 'Africa', '69.213', ''],
#  ['World', 'OWID_WRL', '2015', '7379796992', '', '71.661', '14500'],
#  ['Wuerttemburg', 'OWID_WRT', '2015', '', 'Europe', '', ''],
#  ['Yemen', 'YEM', '2015', '26498000', 'Asia', '66.085', '2496'],
#  ['Yemen Arab Republic', 'OWID_YAR', '2015', '', 'Asia', '', ''],
#  ["Yemen People's Republic", 'OWID_YPR', '2015', '', 'Asia', '', ''],
#  ['Yugoslavia', 'OWID_YGS', '2015', '', 'Europe', '', ''],
#  ['Zambia', 'ZMB', '2015', '15879000', 'Africa', '61.737', '3537'],
#  ['Zanzibar', 'OWID_ZAN', '2015', '', 'Africa', '', ''],
#  ['Zimbabwe', 'ZWE', '2015', '13815000', 'Africa', '59.534', '1759'],
#  ['Ã…land Islands', 'ALA', '2015', '', 'Europe', '', '']]

# %%
gdp=[]
life_expectancy=[]
labels=[]
population=[]
population_plot=[]
continent =[]
color=[]
for i in range (len(tableau)):
    gdp.append(tableau[i][6])
    labels.append(tableau[i][0])
    life_expectancy.append(tableau[i][5])
    population.append(tableau[i][3])
    continent.append(tableau[i][4])
print(len(gdp),len(life_expectancy),len(labels),len(population))

for i in reversed(range(1,len(gdp))):
    k=tableau[i][6]
    l=tableau[i][5]
    m=tableau[i][1]
    n=tableau[i][4]
    if(k=='' or l=='' or m=='' or n ==''):
        del gdp[i]
        del life_expectancy[i]
        del labels[i]
        del population[i]
        del continent[i]

for i in range(1,len(gdp)):
    if (continent[i]== 'Europe'):
        color.append("red")
    if (continent[i]== 'Asia'):
        color.append("blue")
    if (continent[i]== 'Africa'):
        color.append("green")
    if (continent[i]== 'North America'):
        color.append("purple")
    if (continent[i]=='South America'):
        color.append("orange")
    if (continent[i]== 'Oceania'):
        color.append("beige")
    if (continent[i]== 'Antarctica'):
        color.append("brown")
# Out:
# 303 303 303 303

# %%
best_countries=[]
best_lifeExpt=[]
dataFrameG=[]
for i in range(1,len(life_expectancy)):
    gdp[i]=int(gdp[i])
    life_expectancy[i]=float(life_expectancy[i])
    population_plot.append(int(population[i])/1000000)
print(len(gdp),len(life_expectancy),len(color),len(population_plot))

lifexpt_mean=np.mean(life_expectancy[1:])
std_lifexpt=np.std(life_expectancy[1:])
stand_abobeMean=lifexpt_mean+std_lifexpt


del life_expectancy[0]
del labels[0]
del gdp[0]

for i in range(len(life_expectancy)):
    if (life_expectancy[i]>stand_abobeMean):
        best_countries.append(labels[i])
        best_lifeExpt.append(life_expectancy[i])
    
        
dataFrameG=np.vstack(( best_countries,best_lifeExpt))
Test=np.transpose(dataFrameG)
columns = ['Contry','Life Expectancy']
df = pd.DataFrame(data=Test,columns=columns)

df.style.format("{:.20}")
# Out:
# 167 167 166 166
# <style  type="text/css" >
# </style><table id="T_88608864_234a_11eb_a651_8c164510d2f9" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Contry</th>        <th class="col_heading level0 col1" >Life Expectancy</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row0_col0" class="data row0 col0" >Australia</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row0_col1" class="data row0 col1" >82.794</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row1_col0" class="data row1 col0" >Austria</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row1_col1" class="data row1 col1" >81.182</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row2_col0" class="data row2 col0" >Belgium</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row2_col1" class="data row2 col1" >80.969</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row3_col0" class="data row3 col0" >Canada</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row3_col1" class="data row3 col1" >82.026</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row4_col0" class="data row4 col0" >Cyprus</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row4_col1" class="data row4 col1" >80.35</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row5_col0" class="data row5 col0" >Denmark</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row5_col1" class="data row5 col1" >80.475</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row6_col0" class="data row6 col0" >Finland</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row6_col1" class="data row6 col1" >81.196</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row7_col0" class="data row7 col0" >France</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row7_col1" class="data row7 col1" >82.224</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row8_col0" class="data row8 col0" >Germany</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row8_col1" class="data row8 col1" >80.77</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row9_col0" class="data row9 col0" >Greece</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row9_col1" class="data row9 col1" >81.548</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row10_col0" class="data row10 col0" >Hong Kong</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row10_col1" class="data row10 col1" >84.043</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row11_col0" class="data row11 col0" >Iceland</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row11_col1" class="data row11 col1" >82.481</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row12_col0" class="data row12 col0" >Ireland</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row12_col1" class="data row12 col1" >81.344</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row13_col0" class="data row13 col0" >Israel</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row13_col1" class="data row13 col1" >82.34</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row14_col0" class="data row14 col0" >Italy</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row14_col1" class="data row14 col1" >82.828</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row15_col0" class="data row15 col0" >Japan</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row15_col1" class="data row15 col1" >83.879</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row16_col0" class="data row16 col0" >Luxembourg</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row16_col1" class="data row16 col1" >81.636</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row17_col0" class="data row17 col0" >Malta</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row17_col1" class="data row17 col1" >81.896</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row18_col0" class="data row18 col0" >Netherlands</td>
#                         <td id="T_88608864_234a_11eb_a651_8c164510d2f9row18_col1" class="data row18 col1" >81.715</td>
#             </tr>
#             <tr>
#                         <th id="T_88608864_234a_11eb_a651_8c164510d2f9level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_886088

# %%
#population
fig,ax = plt.subplots(1, 1, figsize=(20, 4))
ax.set_xscale("log")


for i in range((len(gdp))): 
    ax.scatter(gdp[i],life_expectancy[i],c=color[i],s=population_plot[i],alpha=0.4)
   
ax.hlines(stand_abobeMean,np.min(gdp),np.max(gdp), color='green',alpha=0.6,label='Life Exceptency standard deviation above the mean ')
ax.hlines(np.mean(life_expectancy),np.min(gdp),np.max(gdp), color='blue',alpha=0.6,label='Average life expectancy')
ax.vlines(np.mean(gdp),(np.min(life_expectancy)),np.max(life_expectancy), color='red',alpha=0.6,label='GDP standard deviation above the mean?')



ax.set_xlabel('GDP per capita (in $)')
ax.set_ylabel('Life exceptency (in years)')
ax.set_title('GDP per capita VS Life exceptency in 2015 log scale')
leg1=ax.legend(prop={"size":10},loc='lower left')


red_patch = mpatches.Patch(color='red', label='Europe')
blue_patch = mpatches.Patch(color='blue', label='Asia')
orange_patch = mpatches.Patch(color='orange', label='South America')
green_patch = mpatches.Patch(color='green', label='Africa')
purple_patch = mpatches.Patch(color='purple', label='North America')
brown_patch = mpatches.Patch(color='brown', label='Antartica')
beige_patch = mpatches.Patch(color='black', label='Oceania')

leg2=ax.legend(handles=[red_patch,blue_patch,orange_patch,green_patch,purple_patch,brown_patch,beige_patch],prop={"size":10},loc='lower right')

ax.add_artist(leg1)
del population[0]

# %%
inequal_country=[]
inequal_lifeExp=[]
highLE_LowGDP_C=[]
highLE_LowGDP=[]
fig2,ax2 = plt.subplots(1, 1, figsize=(20, 4))
ax2.set_xscale("log")
total_gdp=[]
treshold_e=40

for i in range(len(gdp)):
    total_gdp.append(int(gdp[i])*int(population[i])/1000000000)
test=np.std(total_gdp)+np.mean(total_gdp)
for i in range((len(gdp))): 
    ax2.scatter(total_gdp[i],life_expectancy[i],c=color[i],s=population_plot[i],alpha=0.4)

for i in range(len(life_expectancy)):
    if (life_expectancy[i]<np.mean(life_expectancy) and total_gdp[i]>test):
        inequal_country.append(labels[i])
        inequal_lifeExp.append(life_expectancy[i])
        
#ax2.hlines(stand_abobeMean,np.min(gdp),np.max(gdp), color='green',alpha=0.6,label='Life Exceptency standard deviation above the mean ')
#ax2.hlines(np.mean(life_expectancy),np.min(gdp),np.max(gdp), color='blue',alpha=0.6,label='Average life expectancy')
ax2.vlines((np.mean(total_gdp)+np.std(total_gdp)),(np.min(life_expectancy)),np.max(life_expectancy), color='red',alpha=0.6,label='GDP standard deviation above the mean? + One std')
ax2.hlines(np.mean(life_expectancy),np.min(total_gdp),np.max(total_gdp), color='blue',alpha=0.6,label='Average life expectancy')
